# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from pathlib import Path

# %%
# File Structure
path = Path(os.getcwd())
root = Path(path.parent.absolute()) 

train_caption_path = root / 'ROCO' / 'Data' / 'Train' / 'radiology' / 'captions.txt'
train_image_path = root / 'ROCO' / 'Data' / 'Train' / 'radiology' / 'images'

test_caption_path = root / 'ROCO' / 'Data' / 'Test' / 'radiology' / 'captions.txt'
test_image_path = root / 'ROCO' / 'Data' / 'Test' / 'radiology' / 'images'

target_path = root / 'Shared Preprocessed Objects'

# %%
# Parameters that must be defined by the user!!!
FREQUENCY_CUTOFF = 20
EMBEDDING_DIM = 300 # either 200 or 300 for the current path, can be more values otherwise.
BATCH_SIZE = 32
variable_params = {}

# %%
# Get captions from .txt files and parse properly
def get_captions(caption_path):
    ## Reading each image file name and its associated caption
    doc = open(caption_path, 'r', encoding = 'utf-8').read()
    
    splitDoc = doc.split('\n')
    while('' in splitDoc):
        splitDoc.remove('')
    
    descriptions = {}
    for line in splitDoc:
        splitLine = line.split('\t')
        descriptions[splitLine[0]] = splitLine[1]
    
    return descriptions

# %%
train_captions = get_captions(train_caption_path)
test_captions = get_captions(test_caption_path)

print(len(train_captions), len(test_captions))
# Out:
# 65450 8179

# %%
import re
# Treat caption to remove symbols that will not be considered by the model
def treat_captions(data):
    for imageID, caption in data.items():
        caption = caption.lower()
        caption = re.sub(r'[^\w\s]', '', caption)
        data[imageID] = caption
    return data

# %%
train_captions = treat_captions(train_captions)
test_captions = treat_captions(test_captions)

# %%
# add start and end tokens to the captions
def add_start_end_tokens(data):
    final_data = {}
    
    for imageId, caption in data.items():
        final_data[imageId] = 'startseq ' + caption + ' endseq'
    
    return final_data

# %%
train_captions = add_start_end_tokens(train_captions)
test_captions = add_start_end_tokens(test_captions)

# %%
train_captions
# Out:
# {'ROCO_00002': 'startseq  computed tomography scan in axial view showing obliteration of the left maxillary sinus endseq',
#  'ROCO_00003': 'startseq  bacterial contamination occurred after completion of root canal treatment in the tooth which remained with a temporary filling for 15 month endseq',
#  'ROCO_00004': 'startseq  the patient had residual paralysis of the hand after poliomyelitis it was necessary to stabilize the thumb with reference to the index finger this was accomplished by placing a graft from the bone bank between the first and second metacarpals the roentgenogram shows the complete healing of the graft one year later endseq',
#  'ROCO_00005': 'startseq  panoramic radiograph after immediate loading endseq',
#  'ROCO_00007': 'startseq  plain abdomen xray multiple air levels at the midabdomen arrows no radiopaque shadow and no air under the diaphragm endseq',
#  'ROCO_00008': 'startseq  a 3yearold child with visual difficulties axial flair image show a suprasellar lesion extending to the temporal lobes along the optic tracts arrows with moderate mass effect compatible with optic glioma flair hyperintensity is also noted in the left mesencephalon from additional tumoral involvement endseq',
#  'ROCO_00009': 'startseq  showing the subtrochanteric fracture in the porotic bone endseq',
#  'ROCO_00010': 'startseq  post orthodontic treatment root canal therapy done with maxillary incisors endseq',
#  'ROCO_00011': 'startseq  two sequential thrombi in the distal segment of the obtuse marginal 2 om2 endseq',
#  'ROCO_00012': 'startseq  an example of mri image that takes advantage of joint effusion as contrast material in acute scenario 57x46mm 150 x 150 dpi endseq',
#  'ROCO_00013': 'startseq  child with abduction and flexion of right lower extremity and hyperextension of the tibia on the femur associated with dislocation of the left hip probably the result of the dangerous position of adduction in production of pathological dislocation a roentgenogram of the mothers pelvis one week before delivery showed this same deformity in utero endseq',
#  'ROCO_00014': 'startseq  axial t2 haste mr image shows loss of normal trilaminar myometrial architecture and mild focal thinning of placenta at the site of compression of myometrium in front of aorta black arrow just proximal to the bifurcation normal trilaminar signal pattern of myometrium can be seen at other regions white arrows endseq',
#  'ROCO_00015': 'startseq  hydronephrosis appearance in sonography endseq',
#  'ROCO_00017': 'startseq  coronary angiogram demonstrating occluded om1 and om2 arteries endseq',
#  'ROCO_00018': 'startseq  cardiac catheterization showing normal coronaries and a tumor blush endseq',
#  'ROCO_00019': 'startseq  followup coronary angiography and fluoroscopy showed a gap in the stent strut ad a gap in the stent strut endseq',
#  'ROCO_00021': 'startseq  rightsided metatarsal in dorsoplantar projectioncow age group ivcattle 48 years a narrow symphysis that is b indistinct from the bone surface endseq',
#  'ROCO_00022': 'startseq  fourth patients mri endseq',
#  'ROCO_00023': 'startseq  orthopantomograph endseq',
#  'ROCO_00024': 'startseq  focal steatosis of the liver parenchyma endseq',
#  'ROCO_00026': 'startseq  preoperative tte end diastole preop pics endseq',
#  'ROCO_00028': 'startseq  magnetic resonance t2 weighted image showing foraminal extensions of the cysts endseq',
#  'ROCO_00029': 'startseq  posttreatment mriaxial t1weighted contrastenhanced image showing the same lesion as figure 3\xa0 endseq',
#  'ROCO_00030': 'startseq  abdominal ct scan showing pancreatic pseudocyst endseq',
#  'ROCO_00032': 'startseq  axial contrastenhanced computed tomography image of the abdomen 3 months after anti tuberculous treatment showing complete resolution of the lesions endseq',
#  'ROCO_00033': 'startseq  lytic lesions arrows involving the humerus endseq',
#  'ROCO_00034': 'startseq  fluoroscopy image of evar procedure endseq',
#  'ROCO_00035': 'startseq  ap pelvis xray obtained 6 weeks from initial presentation which shows early femoral head collapse endseq',
#  'ROCO_00037': 'startseq  postoperative control following periapical surgery endseq',
#  'ROCO_00038': 'startseq  ct image of the liver shows air in the hepatic veins arrow and aircontrast level in the inferior vena cava arrowhead endseq',
#  'ROCO_00039': 'startseq  sfa perforated after glidewire insertion in an attempt to cross the lesion endseq',
#  'ROCO_00040': 'startseq  postoperative computed tomography scan endseq',
#  'ROCO_00041': 'startseq  18yearold woman with venous tumor thrombus axial t1w fatsaturated postcontrast mr image of the pelvis endseq',
#  'ROCO_00042': 'startseq  xray control of calcaneus drilling endseq',
#  'ROCO_00043': 'startseq  transvaginal image of the maternal pelvis demonstrating cervical length the probe is first advanced into the anterior fornix and then slightly withdrawn so that good image quality is maintained while avoiding placing pressure on the cervix cervical length is measured from internal to external os the endocervical canal is also marked and can be differentiated by its echolucency the anterior and posterior cervical walls are of similar thickness endseq',
#  'ROCO_00044': 'startseq  opg showing a well defined corticated radiolucency containing two supernumerary premolars endseq',
#  'ROCO_00045': 'startseq  computed tomography scan obtained on december 24 2014 7 days before treatmentnotes scan demonstrates a mass in the upper lobe of the left lung multiple enlarged lymph nodes in the mediastinum and pleural effusion arrow indicates abundant pericardial effusion around the pericardium endseq',
#  'ROCO_00046': 'startseq  coronal contrast chest ct image showing the two aberrant arteries white arrow arising directly from the thoracic aorta and the left lower lobe cystic lesion endseq',
#  'ROCO_00047': 'startseq  osteoid osteoma in the femur axial ct scan shows a nidus arrow within the cortex with surrounding dense sclerosis arrowhead endseq',
#  'ROCO_00048': 'startseq  mandibular occlusal view radiograph showing fusion of mandibular teeth with talon cusp with respect to 41 and 42 endseq',
#  'ROCO_00049': 'startseq  intraoperative t2w mr image showing the tumor and the first bbb target endseq',
#  'ROCO_00050': 'startseq  free air beneath the diaphragm at abdominal xray film endseq',
#  'ROCO_00051': 'startseq  posteroanterior radiography immediately before reintervention showing the inferior vena caval loop of the pacemaker lead strongly attached to the endothelium the tip of the electrode is still attached the right ventricular wall at that time an exit block was predominantly existent endseq',
#  'ROCO_00052': 'startseq  après mise en place du drain thoracique endseq',
#  'ROCO_00053': 'startseq  venography of left innominate vein using catheter introduced via right common femoral vein the site of perforation is well seen endseq',
#  'ROCO_00054': 'startseq  ct spine showing a mass at level of c3 with marked osseous destruction endseq',
#  'ROCO_00055': 'startseq  destroid lung due to progressive pulmonary tuberculosis in a 16yearold boy ct scan lung window shows diffuse bilateral small and large airfilled cystic lesions black arrows associated with groundglass attenuation and disseminated miliary micronodular lesions on the right white arrows endseq',
#  'ROCO_00056': 'startseq  view of giant cell tumor of thumb metacarpal preoperatively endseq',
#  'ROCO_00057': 'startseq  mri showing high signals involving the superior sagittal sinus thrombosis on tw1 endseq',
#  'ROCO_00058': 'startseq  color doppler echocardiography parasternal modified short axis view middle lad stenosis was incidentally found on rutine tte it was later confirmed by coronary angiography see movie 13 see additional file 13 endseq',
#  'ROCO_00060': 'startseq  transverse view of lung using computed tomography leukemic infiltration is seen endseq',
#  'ROCO_00063': 'startseq  calculation of mitral valve areamva via planimetry method from parasternal shortaxis view in one patient with mitral annulus calcificationmac after ptmc endseq',
#  'ROCO_00064': 'startseq  catch of the muscles with 50 nonresorbable suture thread and their resection near the insertion eye prosthesis made up of a polymethyl methacrylate pmma ball covered with a polyethylene terephthalate shell dacron endseq',
#  'ROCO_00065': 'startseq  the ap view radiograph of the right hip demonstrates proximal migration of the lesser trochanter endseq',
#  'ROCO_00066': 'startseq  xray arthrogram showing mild contrast tracking along the proximal lateral aspect of the femoral component endseq',
#  'ROCO_00067': 'startseq  48\u2009h reperfusion t2wi shows highsignal infarction smaller than lesion on dwi endseq',
#  'ROCO_00069': 'startseq   computed tomography axial section after injection of contrast medium in parenchymal time showing a large thrombus in the left renal vein extending from the segmental renal veins to the inferior vena cava complicated by cortical infarction endseq',
#  'ROCO_00070': 'startseq  postoperative panoramic radiograph after surgery the costochondral graft was adjusted to the left condyle area and secured on the left mandibular ramus by five bicortical screws for rigid internal fixation endseq',
#  'ROCO_00071': 'startseq  solidcystic teratoma containing different types of tissue like fat albuminous liquid and other solid parts mri t1gradient echo sequence coronal endseq',
#  'ROCO_00072': 'startseq  dental panoramic tomograph from 2016 showing extensive bone loss of the right mandible left coronoid process and ramus endseq',
#  'ROCO_00074': 'startseq  chest radiography shows a mass on the right lower mediastinum endseq',
#  'ROCO_00075': 'startseq  radiationinduced liver disease a 21yearold woman with lymphoma of the right anterior chest wall the patient received 396 gy to the right chest wall ct obtained 5 weeks after the completion of radiation therapy shows a welldefined area of low attenuation in the liver with a sharp demarcation between the area of radiation and the normal liver this is consistent with the straightborder sign of radiation change endseq',
#  'ROCO_00077': 'startseq  underfilled root canal with void endseq',
#  'ROCO_00078': 'startseq  anteriorposterior radiograph of the left shoulder of a 36yearold male patient showing the failed reconstruction of the acromioclavicular ac joint with an allograft because of type 5 ac separation endseq',
#  'ROCO_00080': 'startseq  ct head with iv contrast with an arrow that indicates cerebral venous sinus thrombosis endseq',
#  'ROCO_00081': 'startseq  pelvic xray hours after the ct showed the gastric band and its connecting tube in the lower pelvis endseq',
#  'ROCO_00083': 'startseq  aneurysm of the descending thoracic aorta with a transverse diameter of 31\xa0cm endseq',
#  'ROCO_00085': 'startseq  contrast mri head axial section showing an irregularly enhancing mass in the right medial temporal lobe anteriorly in the close proximity to the cavernous sinus and oculomotor nerve arrow endseq',
#  'ROCO_00086': 'startseq  endovaginal ultrasonography of anal sphincter in a patient with rectal prolapse irregular and asymmetrical appearance of the internal anal sphincter ias arrow without defect a anterior and p posterior endseq',
#  'ROCO_00087': 'startseq  chest xray which confirmed the position of guidewire extending from the right internal jugular vein up to inferior vena cava endseq',
#  'ROCO_00088': 'startseq  sagittal ct angiogram of abdomen demonstrating mechanical fragmentation and displacement of stent endseq',
#  'ROCO_00089': 'startseq  melorheostosis involving the ulnar aspect of the third proximal phalanx note that it takes on the appearance of dripping candle wax endseq',
#  'ROCO_00090': 'startseq  barium swallow demonstrating the obstructive appearance of the gct endseq',
#  'ROCO_00091': 'startseq  pancreatic pseudoaneurysm arrow visualized in color doppler examination  a result of the damage of pancreaticoduodenal artery a complication of ap endseq',
#  'ROCO_00092': 'startseq  mdct angiography showing the location of coa in a 1monthold b girl arrow endseq',
#  'ROCO_00093': 'startseq  anterior uveitis with cystoid macular edemain a 57yearold female with quiescent anterior uveitis peripheral vessel leakage and cystoid macular edema were detected endseq',
#  'ROCO_00094': 'startseq  initial radiograph performed after the injury endseq',
#  'ROCO_00095': 'startseq  the highfrequency color doppler ultrasonography manifestation of the apterium blood of the articulationes interphalangeae of digitus medius of the patients with bone erosion endseq',
#  'ROCO_00096': 'startseq  image of the tmj shows the morphology of the tmj in an asymptomatic volunteer endseq',
#  'ROCO_00097': 'startseq  axial view of petct scan image demonstrates a large hypermetabolic mass with intense uptake of f18 levodopa in the posterior mediastinum near the left atrium which is consistent with paraganglioma endseq',
#  'ROCO_00098': 'startseq  ocular ultrasound of the left eye demonstrating the dislocated lens in the vitreous cavity ocular ultrasound of the left eye at presentation demonstrating the dislocated lens heterogeneous hyperechogenic ovalshaped mass within the vitreous cavity hypoechogenic endseq',
#  'ROCO_00100': 'startseq  collateral circulation from the conus artery to the left anterior descending artery endseq',
#  'ROCO_00101': 'startseq  panoramic radiograph showing extensive radioopaque lesion with welldefined corticated border endseq',
#  'ROCO_00102': 'startseq  ct scan of abdomen and pelvis with iv contrast coronal section showing perinephric hematoma nonobtructive lower pole 6\u2009mm stone and 11\u2009cm obstructive proximal ureteral stone arrow heads marked left perinephric stranding with extension of extracapsular hematoma to distal aorta iliac vessels and presacral space was noted endseq',
#  'ROCO_00103': 'startseq  transthoracic echocardiography showed severely increased aortic root and ascending aorta with intimal flap endseq',
#  'ROCO_00104': 'startseq  peripherally enhancing irregular marginated subcentimeter lesion in segment iva and segment vii of liver suspicious of metastasis endseq',
#  'ROCO_00105': 'startseq  t1 axial image shows hypointense lesions in the pontine region and at the periphery of the pons central pontine myelinolysis is a likely diagnosis however involvement of the temporal lobe and clinical features makes central pontine myelinolysis unlikely endseq',
#  'ROCO_00106': 'startseq  an inflated representation of the right hemisphere of a representative participant medial and lateral views marked with the locations of the regions of interest rois that were studied csv cingulate sulcus visual area pcm precuneus vip ventral intraparietal area p2v putative area 2v pivc parietoinsular vestibular cortex endseq',
#  'ROCO_00107': 'startseq  mri showing that the mass was greatly enhanced with a clear portion in the nearby tissuesmri showing that the mass was greatly enhanced with a clear portion in the nearby tissues endseq',
#  'ROCO_00109': 'startseq  a postoperative axial magnetic resonance image the signal void caused by the presence of the steel and titanium implants obscures any details of the spinal cord or decompression endseq',
#  'ROCO_00110': 'startseq  neonatal chest xray of the larger fetus endseq',
#  'ROCO_00111': 'startseq  coronal t1weighted magnetic resonance imaging showing a tumor with homogenous lowsignal intensity and welldefined margins endseq',
#  'ROCO_00112': 'startseq  ct showing gutta percha point communicating with the periapical area endseq',
#  'ROCO_00115': 'startseq  conventional design for hybrid prosthesis with long distal cantilevers endseq',
#  'ROCO_00116': 'startseq  plain radiographs though less sensitive than computed tomography are an acceptable screening examination a calcific focus is visible just anterior to c1 endseq',
#  'ROCO_00117': 'startseq  coupe axiale dun scanner abdominal passant par le foie après injection du pc endseq',
#  'ROCO_00119': 'startseq  postoperative lateral mri of a female patient three months after surgery endseq',
#  'ROCO_00120': 'startseq  multislice 16 row ecg gated cardiac ct reveals an irregular mass in the right atrium and a moderate pericardial effusion endseq',
#  'ROCO_00121': 'startseq  magnetic resonance angiography image showing almost complete thrombosis of the basilar artery arrow this is an extension from the vertebral artery dissection and thrombosis endseq',
#  'ROCO_00123': 'startseq  a 30yearoldwoman with genital tuberculosis hysterosalpingogram shows a beaded appearance at the right and left fallopian tubes associated with bilateral tubal occlusion arrows there is mild irregularity of the uterine cavity outline endseq',
#  'ROCO_00124': 'startseq  endoscopic ultrasonography revealed avascular a heteroechoic submucosal mass at the posterolateral wall of the duodenum endseq',
#  'ROCO_00125': 'startseq  abdominal computed tomography reveals an illdefined hypodense mass approximately 30  16 cm in diameter in the pancreatic tail endseq',
#  'ROCO_00126': 'startseq  hand xrays showing dense lines at the end of radius and ulna white arrowheads endseq',
#  'ROCO_00127': 'startseq  intraoral periapical radiographs showing illdefined radiolucency displacement and resorption of apical parts of roots of teeth in the areas of lesion 2 endseq',
#  'ROCO_00128': 'startseq  opg showing the area of osteolysis distal to 28 endseq',
#  'ROCO_00129': 'startseq  posteroanterior chest radiograph depicts a solitary pulmonary nodule in the middle third of the right hemithorax arrow slight spiculation of its contour can be appreciated endseq',
#  'ROCO_00131': 'startseq  axial magnetic resonance imaging of case 2 revealed a mass measuring 2020 cm in the retrobulbar compartment of the right orbit causing proptosis endseq',
#  'ROCO_00132': 'startseq  abdominal ct scan showing an exophytic welldefined round mass in the duodenal bulb the mass enhanced as gastric mucosa and was presumed to be a duodenal gastrointestinal stromal tumor gist endseq',
#  'ROCO_00133': 'startseq  panoramic view showing multiple impacted permanent and supernumerary teeth hypoplastic maxillary sinus and slender coronoid process endseq',
#  'ROCO_00135': 'startseq  ct scan showing multiple noncommunicating cysts in liver and kidney endseq',
#  'ROCO_00137': 'startseq  sternal foramen endseq',
#  'ROCO_00139': 'startseq  immediate acl reconstruction postoperative radiographs in ap view endseq',
#  'ROCO_00140': 'startseq  panoramic radiography view of patient before rehabilitation with prostheses in 2014 endseq',
#  'ROCO_00141': 'startseq  ct fistulogram with coronal reconstruction posterior to figure 2 showing the bifurcation of the fistula tract one opening into the external auditory canal shown by right facing arrow and other going to retroauricular region shown by upward arrow endseq',
#  'ROCO_00142': 'startseq  lateral radiograph of reticulum showing clearly demarcable diaphragmatic line and presence of potential and nonpotential metallic densities cranial to diaphragm endseq',
#  'ROCO_00143': 'startseq  abdominal computed tomography sagittal reconstruction a desmoidtype fibromatosis b sigmoid colon involved c ileal loop involved endseq',
#  'ROCO_00144': 'startseq  orthopantomogram showing pinching space of the right tmj endseq',
#  'ROCO_00145': 'startseq  preoperative emergency ct scan showing a cecal tract oval with stricture and adjacent hyperdense elevated and irregular area arrow endseq',
#  'ROCO_00146': 'startseq  preoperative xray showing osteoarthritis of hip joint endseq',
#  'ROCO_00147': 'startseq  ct scan of the same patient in figure 1 demonstrating loculation and septation of the pleural space indicating a phase ii empyema endseq',
#  'ROCO_00148': 'startseq  fivemonth postoperative radiograph showing sinus and onlay graft endseq',
#  'ROCO_00149': 'startseq  ap open mouth view after removing halovest system endseq',
#  'ROCO_00150': 'startseq  magnetic resonance imaging brachial plexus showing hypertrophy of the right plexus with contrast enhancement endseq',
#  'ROCO_00152': 'startseq  axial ct image of the lower pelvis a wellcircumscribed solid tumor is seen in the presacral region with no signs of infiltration in contact with the posterior wall of the rectum arrow endseq',
#  'ROCO_00154': 'startseq  a chest radiograph shows reticulonodular shadowing with bilateral apical lung fibrosis and high density nodules in coal workers pneumoconiosis endseq',
#  'ROCO_00155': 'startseq  txray of knee in profile showing patellar agenesis endseq',
#  'ROCO_00156': 'startseq   mri after 5 months t2weighted image endseq',
#  'ROCO_00157': 'startseq  supraglottic scc  false cord axial contrast ct section through the false cords shows a mass within the right false cord and invading into the right pgs black asterisk endseq',
#  'ROCO_00158': 'startseq  angiography after catheterization of the innominate artery near the origin of the right common carotid and subclavian arteries demonstrating the occlusion of the brachiocephalic trunk bold black arrow note that contrast media is not running along the right vertebral artery due to the retrograde blood flow in the vessel subclavianvertebral steal syndrome concomitant stenosis of the common carotid artery thin black arrow is a manifestation of the generalized atherosclerotic disease stenotic lesions of initial and midportion segments in the subclavian artery were not considered to be that significant for acute treatment in case they progressed we considered endovascular treatment white arrow pacemaker wire endseq',
#  'ROCO_00159': 'startseq  abdomen doppler ultrasound a welldefined hypoechoic area 5339 mm at the quadrate lobe of the liver showing that the internal echo of the mass was heterogeneous endseq',
#  'ROCO_00160': 'startseq  microct image of the rat tibias with the titanium implants endseq',
#  'ROCO_00161': 'startseq  fluoroscopic image of descending aortogram in lateral view showing pda device in situ with minimal residual flow across it endseq',
#  'ROCO_00162': 'startseq   biphalangeal fifth toe endseq',
#  'ROCO_00163': 'startseq  nodal disease axial contrastenhanced ct shows retroperitoneal lymph nodes arrows endseq',
#  'ROCO_00164': 'startseq  mri of the brain showing no mass or enhancing lesion endseq',
#  'ROCO_00165': 'startseq  ct scan of the abdomen with contrast media reveals a largesize intraabdominal mass displacing the adjacent structures in the same scan a suspicious lesion is identified in the right adrenal in some rare cases desmoid tumors may coexist with adrenal or thyroid carcinomas and adrenal adenomas endseq',
#  'ROCO_00166': 'startseq   \u2003ctscan with anastomotic lesion endseq',
#  'ROCO_00168': 'startseq  threedimensional 3d magnetic resonance angiography mra shows bilateral moyamoya disease that is more severe on the right side endseq',
#  'ROCO_00169': 'startseq  minilaparotomyassisted transmesenteric predilation with 0018 guide wire inserted 8 mm into the portal trunk after portal cavernoma recanalization with hydrophilic guide wire endseq',
#  'ROCO_00170': 'startseq  echocardiogram 2\xa0months after biventricular repair demonstrates an apexforming left ventricle and mild residual leftventricular hypertrophy endseq',
#  'ROCO_00171': 'startseq  fluoroscopic spot film of a tube cholangiogram demonstrating contrast bile extravasation bile leak site open arrow from a dehisced isolated right intrahepatic bile duct segment arrow an adjacent biloma is seen with a drain in it endseq',
#  'ROCO_00172': 'startseq  chest xray findings chest radiograph revealed an engorged pulmonary trunk with an abrupt cutoff of pulmonary vascularity in the distal portions bilaterally indicative of the westermark sign arrows endseq',
#  'ROCO_00174': 'startseq  lateralview radiograph of a wrist that underwent arthrodesis with minimal fixation note the dorsal bone plate and the free carpometacarpal joints the kirschner wires that had been holding the bone plate and radiocarpal joint have been removed endseq',
#  'ROCO_00175': 'startseq  xray of the right hip showing an incomplete subtrochanteric fracture of right hip endseq',
#  'ROCO_00177': 'startseq  surveillanceenhanced mri scan showing enlargement of the right adrenal gland seven months after radical cystectomy endseq',
#  'ROCO_00178': 'startseq  motility assayfigure shows motility of the e coli k12 mg1655 wild type wt and strains harboring integrations in the target loci of the flagellar region 1 flga flgai flgf flgfi flgg flggi flgi flgii and flgj flgji 2 μl of the overnight e coli cultures od600 of 10 were inoculated in the middle of the motility plates and incubated for 46 hours at 37c endseq',
#  'ROCO_00179': 'startseq  axial gadoliniumenhanced t1weighted images revealed a large heterogeneous mass with circumferential rim enhancement surrounded by extensive edema was found in the inferior part of the right temporal lobe small homogeneous lesions with limited edema could also be seen in the left temporal lobe endseq',
#  'ROCO_00181': 'startseq  venogram demonstrating restoration of venous outflow following angioplasty and stent placement endseq',
#  'ROCO_00182': 'startseq  a computed tomography scan showing a mass in the gallbladder endseq',
#  'ROCO_00188': 'startseq  chest ct slide highlighting distant lung metastasis left paraspinally endseq',
#  'ROCO_00189': 'startseq  concentric reduction of both femoral heads after close reduction endseq',
#  'ROCO_00192': 'startseq  intraoral periapical radiograph of the patient depicting unusual morphology of mandibular left second premolar endseq',
#  'ROCO_00193': 'startseq  xray showing healing fractures in seven ribs of a twomonthold baby endseq',
#  'ROCO_00194': 'startseq  erect abdominal radiograph radiograph showing bullet in the upper left quadrant of the abdomen endseq',
#  'ROCO_00195': 'startseq  mri scan showing the prostatic neoplasm without a neoplasm of the bladder or other areas of the urethra but with skeletal metastasis endseq',
#  'ROCO_00196': 'startseq  computed tomography with contrast medium portal phase the presence of abscess was suspected at the right lobe of the liver endseq',
#  'ROCO_00197': 'startseq  magnetic resonance of abdomen showing two lesions within the right lobe of the liver along the peripheral surface black arrows endseq',
#  'ROCO_00198': 'startseq  basal ganglia calcification unenhanced ct image of patient number 2 shows punctate calcification in the head of the left caudate nucleus arrows endseq',
#  'ROCO_00199': 'startseq  occlusal radiograph showing permanent unerupted canine and retained deciduous teeth endseq',
#  'ROCO_00201': 'startseq  diverticular formation on fundus level with cascadelike emptying image into the stomach endseq',
#  'ROCO_00202': 'startseq  plain abdominal xray after 3 days endseq',
#  'ROCO_00203': 'startseq  soft tissue bankart lesion with a tear of the anterior inferior labrum and an adjacent small fullthickness mild 25 chondral defect over the anterior inferior glenoid arrow on an axial proton density sequence endseq',
#  'ROCO_00204': 'startseq  brain ct obtained 6 days after cerebral angiography shows improved sulcal obliteration of right cerebral hemisphere ct  computed tomography endseq',
#  'ROCO_00207': 'startseq  ctscan image showing an esophagus thickened wall near the aortic stent graft endseq',
#  'ROCO_00208': 'startseq  right anterior obliquecranial view of left main coronary artery with an anomalous origin off the right sinus of valsalva with interarterial course endseq',
#  'ROCO_00209': 'startseq  no new contrast enhancement nor progression seen after treatment with fluconazole endseq',
#  'ROCO_00210': 'startseq  a computed tomography scan of the chest shows the main pulmonary artery was obstructed circumferentially endseq',
#  'ROCO_00211': 'startseq  before pdt fluorescein angiography shows a predominantly classic subfoveal cnvabbreviations cnv choroidal neovascularization pdt photodynamic therapy endseq',
#  'ROCO_00212': 'startseq  coexisting intrauterine and cervical pregnancy endseq',
#  'ROCO_00213': 'startseq  radiographic observations at the time of the initial consultation showing an osteolytic lesion with an osteosclerotic change to the femoral neck arrows endseq',
#  'ROCO_00214': 'startseq  plain chest posteroanterior radiograph shows a mass of homogenous opacity occupying the entire left hemithorax endseq',
#  'ROCO_00216': 'startseq  the tibial tubercletrochlear groove tttg distance is determined by a line from the most anterior point of the tibial tuberosity to the line running through the trochlear groove orange modified from cooney et al28 with permission endseq',
#  'ROCO_00217': 'startseq  orthopantomograph opg showing radiolucency extending from 13 to 17 regions with 16 root resorption and root displacement in 17 14 endseq',
#  'ROCO_00219': 'startseq  nineyear old girl presented with leftside orbital trauma and third cranial nerve palsy with ptosis later diagnosed with leftside dual ophthalmic arteries with external carotid artery eca and internal carotid artery ica origins left lateral view angiogram of head shows ophthalmic artery variant black arrow and meningoophthalmic artery anomaly white arrow the ophthalmic artery with internal carotid artery origin broken arrow is visible because of injected external carotid artery overflow endseq',
#  'ROCO_00220': 'startseq  contrast enhanced computed tomography of abdomen showing the small enhancing periampullary neuroendocrine tumor arrow endseq',
#  'ROCO_00222': 'startseq  radiograph of chest and abdomen of a neonate following cardiac surgery showing a misplaced intravenous line into a hepatic vein the intravenous line has been introduced via the right femoral vein endseq',
#  'ROCO_00225': 'startseq  coronal thoracic spine mri image t2w abnormal high signal in t5 and t8 vertebral bodies with right atypical thoracic scoliosis endseq',
#  'ROCO_00226': 'startseq  computed tomography scan shows a mass arising in the retro peritoneum endseq',
#  'ROCO_00230': 'startseq  coronal slice of the chest ct scan demonstrating multiple cavitating lung lesions endseq',
#  'ROCO_00231': 'startseq  a ct scan of chest showing bronchiectatic changes in the right lower lobe endseq',
#  'ROCO_00232': 'startseq  chest xray pa showing the position of the gun nails endseq',
#  'ROCO_00233': 'startseq  transverse highresolution usg grey scale image 711\u2005mhz image a of medial aspect of distal foot showing hypoechoic lesions with central hyperechoic fungal grains arrow endseq',
#  'ROCO_00234': 'startseq  a 54yearold woman with adenocarcinoma of the sigmoid colon without mucinous differentiation bilateral adrenal metastases asterisks are seen on this axial noncontrast ct image with amorphous calcification arrow within the right adrenal metastasis endseq',
#  'ROCO_00235': 'startseq   abdominal ultrasonography shows a large amount of fluid and cysts into the peritoneal cavity arrow endseq',
#  'ROCO_00236': 'startseq  abdominal ct image showing marked cecal dilatation endseq',
#  'ROCO_00237': 'startseq  mri image of the lesion axial slice green arrows indicate the area affected by the lesion endseq',
#  'ROCO_00238': 'startseq  28yearold male with massive hemoptysis and recurrent intractable hemoptysis frontal chest radiograph rightsided aortic arch diminutive left hilum small left lung hemithorax and leftsided rib notching white arrows endseq',
#  'ROCO_00239': 'startseq  a repeated petct reveals disseminated multiple bony lytic lesions with increased fdg uptake endseq',
#  'ROCO_00240': 'startseq  isolated bronchial malinosculation  bronchial atresia axial ct chest section in lung window shows a mucoid impacted bronchus black arrow supplying the apicoposterior segment of the left upper lobe with hyperinflation white arrow of the involved segment endseq',
#  'ROCO_00241': 'startseq  initial computed tomography ct scan of the abdomen crosssectional image of the mid portion of two intussusceptions arrows illustrates small bowel invagination of the small bowel no evidence of bowel obstruction endseq',
#  'ROCO_00242': 'startseq  transthoracic echocardiogram showing patent ductus arteriosus with flow blue from the pulmonary artery to the aorta pa pulmonary artery da ductus arteriosus and ao aorta endseq',
#  'ROCO_00243': 'startseq  lateral radiograph of the right knee demonstrating 2 patellar tunnels and 1 tunnel in the femur for case 1 endseq',
#  'ROCO_00244': 'startseq  the radiograph at the time of frame removal showed widened pin holes and a hypertrophic partial union endseq',
#  'ROCO_00245': 'startseq  method for determining cardiothoracic ratiodigital posterioranterior chest radiograph cxr with maximal cardiac diameter in red and maximal thoracic diameter in green cardiothoracic ratio ctr is 057 endseq',
#  'ROCO_00246': 'startseq  plain lateral radiograph of lumbosacral region shows widened sacral neural foramina arrow endseq',
#  'ROCO_00247': 'startseq  chest radiograph showing no abnormality endseq',
#  'ROCO_00248': 'startseq  proximal part of left coronary artery in bmode modified parasternal short axis view lm  left main coronary artery lad prox  proximal part of the left anterior descending coronary artery cx prox  proximal part of the left circumflex coronary artery diagonal  proximal part of first diagonal artery endseq',
#  'ROCO_00249': 'startseq  abdominal ct scan the ct scan from this patient shows a mildly enlarged spleen measuring 14 cm in longitudinal dimension he had multiple splenic lacerations however and this slice shows a 37 cm transverse splenic laceration endseq',
#  'ROCO_00250': 'startseq  bare area shunt an intrahepatic shunt white arrow is seen arising from a peripheral branch of right portal vein black arrow and draining into the intercostal veins arrowhead endseq',
#  'ROCO_00252': 'startseq  radiographic image illustrating the measurement of the first mtt shortening in relation to the second where the value is expressed as the difference ab endseq',
#  'ROCO_00253': 'startseq  plain film radiograph showing method for measurement of disc height ratio dhr dhr  a  bh endseq',
#  'ROCO_00254': 'startseq  postobturation endseq',
#  'ROCO_00255': 'startseq  us image of a carotid artery with the expertdrawn contours delineating the lib red solid contour and mab yellow hollow point contour endseq',
#  'ROCO_00257': 'startseq  abdominal radiograph showing a markedly dilated small intestine endseq',
#  'ROCO_00259': 'startseq  example of the dose distribution in intraoperative planning on a representative patient on the transrectal ultrasound image the focal clinical target volume dark brown planning target volume cyan prostate red urethra green and rectum blue images are contoured the dose distributions are shown in light green 100  145 gy and purple 150  2175 gy the focal clinical target volume received a dose of approximately 150 and the planning target volume received a dose of approximately 100 rectum sparing in the dose distribution is apparent endseq',
#  'ROCO_00260': 'startseq  color doppler transthoracic echocardiography parasternal short axis view proximal lad and proximal cx stenoses were incidentally found on rutine echocardiographic examination they were later confirmed by coronary angiography see movie 12 see additional file 12 endseq',
#  'ROCO_00262': 'startseq  breast ultrasonography of the axillary lesion a minimum of 20 irregular masses of dispersed sizes were observed surrounding the suspected metastatic left axillary lymph node the smallest and greatest diameters observed were 5 and 35 mm respectively endseq',
#  'ROCO_00263': 'startseq  followup 18ffdg petct 8 years after operation shows no evidence of cancer recurrence endseq',
#  'ROCO_00265': 'startseq  unicornuate uterus with a single right horna coronal image of a unicornuate uterus in a 25yearold woman shows an almost tubular endometrial cavity asterisk and a single right uterine cornu endseq',
#  'ROCO_00266': 'startseq   twin a magnetic resonance imaging absence of the t1weighted high signal corresponding to the rectum endseq',
#  'ROCO_00267': 'startseq  hallucal sesamoids axial view radiograph of the forefoot shows normal hallucal sesamoids arrows and their articulation with the first metatarsal head asterisk endseq',
#  'ROCO_00269': 'startseq  axial view of same tooth reconstructed from 3d accuitomo 170 6 fov arrow show vertical fracture in axial image endseq',
#  'ROCO_00270': 'startseq  upper gastrointestinal series showing contrast accumulation in dilated stomach and duodenum endseq',
#  'ROCO_00272': 'startseq  chest radiography from case 1 showing a pneumomediastinum endseq',
#  'ROCO_00273': 'startseq  axial mri with contrast showing heterogenous enhancing solid and cystic component of tumor endseq',
#  'ROCO_00274': 'startseq  chest xray showing rightsided pneumothorax endseq',
#  'ROCO_00275': 'startseq  mmode showing right ventricular diastolic indentation endseq',
#  'ROCO_00276': 'startseq  illustrates a thyroid nodule within calipers with microcalcifications endseq',
#  'ROCO_00277': 'startseq  opg showing sialolith mimicking an impacted canine tooth endseq',
#  'ROCO_00279': 'startseq  ultrasound exam no uterus identified behind the bladder endseq',
#  'ROCO_00280': 'startseq  a 37yearold male with a history of hl treated with chemotherapy and mediastinal radiation 5\xa0years ago axial contrastenhanced ct image reveals anterior mediastinal lymphadenopathy with peripheral calcification arrows endseq',
#  'ROCO_00281': 'startseq  computed tomography ct guided needle biopsy of the left upper lobe lesion endseq',
#  'ROCO_00282': 'startseq  an xray of the wrist demonstrated no significant findings such as rheumatoid arthritis distal radius or carpal fracture endseq',
#  'ROCO_00283': 'startseq  magnetic resonance scan detailing radially located median nerve endseq',
#  'ROCO_00284': 'startseq  multislice ct coexistingt1 areas of high enhancement are visible at the lower parotid pole with multiple cervical lymphadenopathies at the level iii and iv cervical nodes endseq',
#  'ROCO_00285': 'startseq  followup brain magnetic resonance imaging  fluid attenuated inversion recovery sequencing showed resolution of bilateral occipital lesions with symmetrical putaminal high signal abnormalities black arrows endseq',
#  'ROCO_00286': 'startseq  obturation radiograph endseq',
#  'ROCO_00287': 'startseq   preoperative computed tomography scan lipid formation without any capsular structure in the perineum endseq',
#  'ROCO_00288': 'startseq  postoperative echocardiography showing a reduction of left atrial size endseq',
#  'ROCO_00289': 'startseq  the axial ct scan shows an infiltrating tumor mass with bony destruction of lateral orbital wall and skullbase endseq',
#  'ROCO_00290': 'startseq  xray of right foot showing metatarsal osteomyelitis extensive destruction of the fifth metatarsal bone is present endseq',
#  'ROCO_00291': 'startseq  contrastenhanced axial ct brainmultiple solid enhancing cortical lesions with dense gyriform calcifications are seen in both cerebral hemispheres\xa0ct computed tomography endseq',
#  'ROCO_00292': 'startseq  right r lateral recumbent radiograph of the thorax day 1 note the cardiomegaly and dilated tortuous pulmonary lobar arteries endseq',
#  'ROCO_00293': 'startseq  lymphoscintigraphic findings of the patient with chylothorax of unclear etiology abnormal tracer accumulation was seen in the left thorax endseq',
#  'ROCO_00294': 'startseq  minimal signal increases in dentate nucleus in both serebellar hemispheres in axial proton densityweighed pdweighted images endseq',
#  'ROCO_00295': 'startseq  metapex intracanal medicament endseq',
#  'ROCO_00296': 'startseq  ballon occluded retrograde venogram thick arrow  gastric varices thin arrow  balloon catheter arrow heads inflow route endseq',
#  'ROCO_00297': 'startseq  t2gre at the level of the caudate nucleus showing 5 punctate hypointense lesions at the greywhite matter junctions arrows identify two lesions endseq',
#  'ROCO_00298': 'startseq  a 62yearold man with rectal gist fused fdgpetct image in the axial plane shows a large intensely fdgavid mass arrow closely abutting and displacing the rectum arrowhead physiologic fdg activity is seen in the urinary bladder endseq',
#  'ROCO_00301': 'startseq  a midline sagittal 2dct study shows marked ventral degenerative spondylotic changes at the c5 and c6 level what was not seen on this study but visualized on the mr was marked oyl contributing to dorsolateral cord compression at the c3c4 c5c6 c6c7 and the c7t1 levels endseq',
#  'ROCO_00304': 'startseq  high uptake of nuclides in the right condyle endseq',
#  'ROCO_00305': 'startseq  xray of the kidney and urinary bladder shows calcific specks arrow in the left hemipelvis with double j stent on the right side endseq',
#  'ROCO_00306': 'startseq  enteroclysis reveals a short segment of jejunal stricture arrow with central ulceration endseq',
#  'ROCO_00308': 'startseq  linear endoscopic ultrasound gfuct240 which shows pancreatic body mass and passage of 22gauge needle echotip ultra echo22 fine needle aspiration was performed via transgastric approach and three passes were made endseq',
#  'ROCO_00309': 'startseq  anteriorposterior xray 6 weeks after operation showing unchanged position and signs of consolidation endseq',
#  'ROCO_00310': 'startseq  coronal view of a temporal maximum intensity projection visualizing part of the middle cerebral artery including the m1 m2 and m3 segments intensity differences from proximal to distal in a nonaffected vessel can reach up to 450 hu and higher vessel occlusions vessel wall calcifications collateral flow clip and stent artifacts have a large influence on the continuity of intensity values along the vessel endseq',
#  'ROCO_00311': 'startseq  xray of the spine in anteriorppsterior projection after dorsal spondylodesis endseq',
#  'ROCO_00312': 'startseq  venous phase ct shows a dubious new finding suggesting a minimal vascular abnormality within the pseudocyst endseq',
#  'ROCO_00313': 'startseq  intraoral periapical radiograph taken to check position of the miniimplant endseq',
#  'ROCO_00314': 'startseq  aneurysmal dilatation of the right atrial appendage raa which was detected in the 21st week of gestation with fetal echocardiography raa right atrial appendage ra atrium rv right ventricle la left atrium lv left ventricle endseq',
#  'ROCO_00315': 'startseq  unstable dislocated flexiondistraction fracture type c1 according to the ao classification white arrows combined with dislocation in the sternal angle black arrow and retrosternal hematoma black arrowhead endseq',
#  'ROCO_00317': 'startseq  computed tomography scan interpreted as cholelithiasis despite a previous cholecystectomy double arrows point to extrabiliary gallstones endseq',
#  'ROCO_00318': 'startseq  intraoperative radiograph of the pelvis with an acetabular reamer placed in the underdeveloped native acetabulum prior to acetabular reaming endseq',
#  'ROCO_00320': 'startseq  axial t2weighted mri demonstrates normal basal ganglia thalamus and cerebellum arrows with mild hyperintensity of the cerebral cortex and white matter asterix endseq',
#  'ROCO_00321': 'startseq  late venous confluence of right renal vein in 49yearold male voluntary kidney donor coronal maximum intensity projection image shows late venous confluence of right renal vein white arrow endseq',
#  'ROCO_00322': 'startseq  positron emission tomographycomputed tomography coronal slice adenoma of the parathyroid that incidentally tookup 18ffluorocholine suvmax 34 endseq',
#  'ROCO_00323': 'startseq  opg showing resected coronoid processes and extracted third molars endseq',
#  'ROCO_00325': 'startseq  contrastenhanced coronal computed tomography image demonstrates the persistent left superior vena cava white arrows and the coarctation connecting from the tubular arch hypoplasia white arrowhead endseq',
#  'ROCO_00326': 'startseq  mammography showing breast tumor endseq',
#  'ROCO_00327': 'startseq  abdominal aorta after the coarctation segment and iliac arteries endseq',
#  'ROCO_00329': 'startseq  hypoechoic ovoid heterogeneous mass arising from muscularis propria on endoscopic ultrasound endseq',
#  'ROCO_00330': 'startseq  mri crosssectional view arrow showing t2weighted hypointense lesion within the pancreatic body endseq',
#  'ROCO_00331': 'startseq  intraoral periapical radiograph at 6 months endseq',
#  'ROCO_00334': 'startseq  coronal computed tomography of the neck clearly showing the fish impacted in cervical esophagus endseq',
#  'ROCO_00335': 'startseq  abdominal ctscan identify a small calcified spleen yellow arrow endseq',
#  'ROCO_00336': 'startseq  xray on admission showing left homogenous opacity and pulling of the mediastinum towards the same side endseq',
#  'ROCO_00337': 'startseq  upper contrast study gastric distension with no opacification of the bulb or the duodenum endseq',
#  'ROCO_00338': 'startseq  protondensity fat saturation coronal sequence demonstrating the bony prominence at the femoral headneck junction arrow also evident is a subtle adjacent articular cartilage signal irregularity consistent with chondrosis endseq',
#  'ROCO_00339': 'startseq  axial t2weighted image of mri showing hyperintensity at the center and hypointensity at periphery suggesting peripheral tumor location with central intratumoral hematoma mri  magnetic resonance imaging endseq',
#  'ROCO_00340': 'startseq  ct scan with shunt tube prior to etv note the absence of csf in subarachnoid spaces endseq',
#  'ROCO_00342': 'startseq  radiograph of test site at 9 months in relation to 46 and 47 endseq',
#  'ROCO_00343': 'startseq  axial image demonstrating intramural gas affecting both small and large bowels endseq',
#  'ROCO_00344': 'startseq  color doppler sonography ulcerated atherosclerotic plaque causing highgrade stenosis of the internal carotid artery endseq',
#  'ROCO_00345': 'startseq  coronal t2weighted mri shows a lack of normal signal void of the left internal carotid artery endseq',
#  'ROCO_00346': 'startseq  a coronal view showing the cyst and bladder endseq',
#  'ROCO_00347': 'startseq  computed tomography chest demonstrating cavitary lung lesions yellow arrowheads for interpretation of the references to colour in this figure legend the reader is referred to the web version of this article endseq',
#  'ROCO_00348': 'startseq  mri t1 image sagittal view noncontrast fat saturated showing fluid level endseq',
#  'ROCO_00349': 'startseq  subcutaneous soft tissue mass measuring 120  103  47 cm3 in the vicinity of prior greater saphenous vein without abnormal enhancement endseq',
#  'ROCO_00351': 'startseq  an expansile lytic mass involving right zygoma and lateral wall of right orbit contrast enhancing computed tomography endseq',
#  'ROCO_00352': 'startseq  patient 8 with symptom recurrence at month 9 with a monthly episode of cholangitis nonconclusive mri transparietohepatic cholangiography was done showing absence of stricture good contrast passage to the jejunum endseq',
#  'ROCO_00354': 'startseq  contrastenhanced ct scan of the abdomen demonstrating the left retroperitoneal mass arrow along with a smaller mass measuring 75 cm originating from the ileal mesentery star endseq',
#  'ROCO_00355': 'startseq  case 2 preoperative orthopantomogram endseq',
#  'ROCO_00356': 'startseq  radiographie montrant une ostéolyse des genoux et une périostite chez un 2 mois et 22 jours pris en charge pour syphilis congénitale révélée par une fracture spontanée endseq',
#  'ROCO_00357': 'startseq  sonography of the patients left breast showing hypoechoic mass with solid appearance and multiple cystic changes endseq',
#  'ROCO_00358': 'startseq  splenic hemorrhage arrow endseq',
#  'ROCO_00359': 'startseq  magnetic resonance pancreatography 1 month after trauma leak of pancreatic fluid 1 arising from the cephalic part of the main pancreatic duct 2 consistent with a ductal laceration endseq',
#  'ROCO_00360': 'startseq  abutment surface in group b original magnification 330 endseq',
# ...
#  'ROCO_01136': 'startseq  pathological specimen demonstrating three different approaches for selective amygdalohippocampectomy endseq',
#  'ROCO_01137': 'startseq  radiograph of shoulder in anteriorposterior view showed a small calcific deposit arrowhead and a possible fracture line arrow in the posterior area of the acromial process at right acromioclavicular joint the possible fracture line was found after performing ultrasonography examination endseq',
#  'ROCO_01138': 'startseq  postoperative magnetic resonance imaging mri of the patient 6 months of follow up endseq',
#  'ROCO_01139': 'startseq  single tooth xray showing a constant bone level 7\xa0months after implant placement endseq',
#  'ROCO_01141': 'startseq  postoperative xray of the pelvis showing sclerosis over the margins of excised bone endseq',
#  'ROCO_01142': 'startseq  fdg petct image of the breast metastasisfused fdg petct images showing an intense focal fdg uptake in the right breast coinciding with a dense breast nodule on ct images the hot iron fdg pet scale represents intensity of fdg uptake varying from black at the weakest intensity to white at the strongest endseq',
#  'ROCO_01143': 'startseq  coronal section construction of the same patient as in fig 1 in the venous phase comparison of mpr in the arterial phase and portal venous phases showed that the portal venous phase was superior to the arterial phase due to the clear contrast between relatively lowdensity bile in the bile duct and ambient tissues mpr multiplanar reconstruction endseq',
#  'ROCO_01144': 'startseq  a lymph node of a case with round shape endseq',
#  'ROCO_01145': 'startseq  ct angiogram showing the left subsegmental renal artery thrombosis arrow endseq',
#  'ROCO_01146': 'startseq  image showing ballooning of lesion in distal circumflex coronary artery endseq',
#  'ROCO_01147': 'startseq  chest xray obtained preoperatively demonstrates hypoinflation of the right lung endseq',
#  'ROCO_01148': 'startseq  preoperative radiograph revealing midroot connections between the root canals endseq',
#  'ROCO_01149': 'startseq  transthoracic echocardiogram short axis of aorta view endseq',
#  'ROCO_01150': 'startseq  t1weighted cardiac mri short axis view demonstrating early enhancement ratios in the posterior epicardium and myocardium soon after gadolinium injection with sparing of the subendocardium blue arrow endseq',
#  'ROCO_01151': 'startseq  chest radiograph obtained with portable machine of semirecumbent adult patient with enterovirus d68associated acute respiratory distress syndrome on hospital day 3 endseq',
#  'ROCO_01152': 'startseq  postoperative doppler sonogram demonstrating normal pulsatile flow of the right hepatic artery with a resistive index of 06 endseq',
#  'ROCO_01153': 'startseq  contrast imaging ct scan umbilical fat hernia endseq',
#  'ROCO_01155': 'startseq  baseline 2d tee demonstrating mobile echogenic thrombus within right superior pulmonary vein rspv  right superior pulmonary vein la  left atrium thrombus  pulmonary vein thrombus endseq',
#  'ROCO_01156': 'startseq  still from a bssfp cine realtime sequence in a 30week fetus with a large right ventricular diverticulum arrowed r right ventricle l left ventricle endseq',
#  'ROCO_01157': 'startseq  the measurement method of coracoclavicularcc distance on the anteroposterior radiograph endseq',
#  'ROCO_01158': 'startseq  ap head arteriography ccf after treatment with endovascular approach endseq',
#  'ROCO_01159': 'startseq  thoracic xray multiple pulmonary nodules are identified with upper lobe predominance note that some nodules show cavitation endseq',
#  'ROCO_01161': 'startseq  ap view of proximal fibula fracture endseq',
#  'ROCO_01162': 'startseq  radiograph to ensure the stability of the graft endseq',
#  'ROCO_01163': 'startseq  axial ct angiography image at the level of aortic sinus shows giant aneurysm of left anterior descending artery short arrow with aneurysm of right coronary artery long arrow endseq',
#  'ROCO_01165': 'startseq  developing nerves in the mouse spinal cord endseq',
#  'ROCO_01166': 'startseq  xray of urinary bladder taken on 07 march 2005 shows prostatic calcification there is a radio opaque shadow in the region of urinary bladder which is probably a vesical calculus arrow endseq',
#  'ROCO_01168': 'startseq  osteopathia striata radiograph of the pelvis showing alternating sclerotic bands in the iliac wings marked endseq',
#  'ROCO_01169': 'startseq  chorioangioma post embolization image showing liquid glue used for embolization of feeding vessel endseq',
#  'ROCO_01170': 'startseq  t1 weighted fat saturated mr image after iv application of contrast medium coronal the arrow is pointing to a fistulating formation spreading in the gluteal muscles on the left side with typical rim enhancement and central liquid components the soft tissue mass seen in midline has a centrally necrotizing appearance endseq',
#  'ROCO_01172': 'startseq  computed tomography scan with contrast reveals the cutoff of the left upper lobe of the bronchial artery endseq',
#  'ROCO_01173': 'startseq  ultrasound image of the antrum of the first patient the antrum is dilated with homogenous echogenic content corresponding to solid contents endseq',
#  'ROCO_01174': 'startseq  orthopantomogram exhibiting single rooted primary mandibular first molar and missing maxillary second premolars and right mandibular second molar endseq',
#  'ROCO_01177': 'startseq  anteroposterior skull radiograph showed excessive aeration of the frontal sinuses osteopenia and total loss of teeth because of dentinogenesis imperfecta endseq',
#  'ROCO_01178': 'startseq  control computed tomography scan showed small fluid accumulation and pneumocephalus endseq',
#  'ROCO_01179': 'startseq  left coronary angiogram in rao view demonstrating the proximally stenosed circumflex artery continuing as the distal right coronary artery after giving off the large obtuse marginal and posterior descending arteries endseq',
#  'ROCO_01180': 'startseq  periventricular represented in light grey and deep represented in dark grey wm masks endseq',
#  'ROCO_01181': 'startseq  right femur radiograph note metaphyseal modelling defects and characteristic lucent bands arrow endseq',
#  'ROCO_01182': 'startseq  tdm objectivant une tumeur de la loge parotidienne endseq',
#  'ROCO_01184': 'startseq  coronal ct with oral contrast shows progression of bilateral femoral head osteonecrosis there is also diffuse marrow signal abnormality of the visualized pelvis and right proximal femur arrow also believed to be consistent with osteonecrosis by imaging endseq',
#  'ROCO_01185': 'startseq  computed tomography of brain bone window computed tomography brain scan showing multiple lytic lesions in the calvarium arrow endseq',
#  'ROCO_01186': 'startseq  axial ct scan showing the mandibular lesion endseq',
#  'ROCO_01187': 'startseq  endoscopic ultrasoundguided paracentesis of minimal ascites through the stomach endseq',
#  'ROCO_01188': 'startseq  axial image showing extensive hepatic pvg endseq',
#  'ROCO_01189': 'startseq  liver metastasis segment viii endseq',
#  'ROCO_01190': 'startseq  paraaxial hrct image of the left temporal bone in a patient with severe vertigo post stapedectomy the stapes prosthesis is dislocated and lies partly within the vestibule arrow endseq',
#  'ROCO_01191': 'startseq  hypoenhancing focus within the right anterior sella consistent with pituitary microadenoma endseq',
#  'ROCO_01192': 'startseq  image scannographique zone de contusion hépatique délimitée par les flèches noires avec des bulles dair à lintérieur montrées par une flèche blanche avec présence déclats de balle en sous cutané et dans le parenchyme hépatique endseq',
#  'ROCO_01193': 'startseq  upper contrast study oesophageal stenosis endseq',
#  'ROCO_01195': 'startseq  three months after the infarction only minor irregularities in the distal part of the lad remained left anterior oblique lao projection endseq',
#  'ROCO_01196': 'startseq  a radiograph of the same patient made 1\xa0week after periacetabular osteotomy showing good coverage of the femoral head without fracture of the posterior column the accelerated rehabilitation protocol was applied to the patient endseq',
#  'ROCO_01197': 'startseq  68gadotatatepet with multiple bone metastases in the spine the rips and at the skull base marked by arrows physiologic tracer uptake in the liver the kidneys the adrenals the stomach pancreas spleen and the small bowel this 41 year old female sdhb mutation carrier had first undergone resection of a malignant carotid body tumor with regional lymph node metastases seven years earlier endseq',
#  'ROCO_01198': 'startseq  t1 weighted mri of the brain obtained after administration of intravenous gadolinium demonstrating a ring enhancing metastasis in the posterior left parietal lobe endseq',
#  'ROCO_01199': 'startseq  liver ultrasound showed derangement of the liver parenchyma architecture with fine nodular patterns on the liver surface with a hypertrophied left hepatic lobe no intra hepatic duct dilatation was seen endseq',
#  'ROCO_01200': 'startseq  example of invivo duplex mode ultrasound imaging of the heart from a healthy subject image shows the filling of the left ventricle during diastole red color is upward flow the blood flow velocity cdi mode is colorcoded on top of the grayscale tissue image bmode the rectangular rois indicate the regions used for myocardial tissue velocity and mitral blood flow velocity quantification the frame rates of the cdi and bmode image sequences were 100 and 33 hz respectively the ecg and respiration signals are visible at the bottom of the figure endseq',
#  'ROCO_01201': 'startseq  chest xray bilateral pleural effusions and extensive interstitial reticulonodular shadowing endseq',
#  'ROCO_01202': 'startseq  intraop iitv imageshows fixation with pedicle screws and transpedicular curettage of the body of l1 vertebra with a curette to remove the tubercular material iitv \xa0image intensifier television endseq',
#  'ROCO_01203': 'startseq  saphenous nerve is located outside of pes anserine tendons pat pes anserine tendons sn saphenous nerve endseq',
#  'ROCO_01204': 'startseq  sample of preoperative cone beam radiographic evaluation right side shows the vertical residual ridge like 474 mm endseq',
#  'ROCO_01205': 'startseq  ct scan of renal stones in a horseshoe kidney endseq',
#  'ROCO_01206': 'startseq  the implant was restored following a healing period of 6 months the patient has been followed for 1 year now endseq',
#  'ROCO_01207': 'startseq  abdominal ct scan july 2011 confirming pneumoperitoneum endseq',
#  'ROCO_01208': 'startseq  ultrasonography showing an area of focal eventration of the diaphragm with adjacent protrusion of perinephric fat endseq',
#  'ROCO_01209': 'startseq  a transesophageal echocardiographic scan showing an intraluminal pyramidal lesion 14 cm15 cm in size with an irregular surface on the anterior wall of the descending aorta arrow endseq',
#  'ROCO_01210': 'startseq  neck ct a reveals a large heterogeneous mass that has replaced the left lobe of the thyroid gland endseq',
#  'ROCO_01211': 'startseq  ct scan showing obliterated frontal sinus due to multiple surgeries endseq',
#  'ROCO_01212': 'startseq  sagittal images showed an occlusion of the lower branch of the left upper pulmonary vein lupv as little contrast enhancements arrow la left atrium lupv left upper pulmonary vein lv left ventricle endseq',
#  'ROCO_01214': 'startseq  contrastenhanced mri after the first operation showing a leftsided vs endseq',
#  'ROCO_01216': 'startseq  mri shows asymmetrical soft tissue mass with a stringy appearance surrounding the thoracic vertebral bodies on november 15 2009 an mri was performed the upper arrow indicated soft tissue masses with a stringy appearance surrounding the thoracic vertebral bodies and the lower arrow suggested a soft tissue mass in the left kidney endseq',
#  'ROCO_01217': 'startseq  chest radiograph taken 1 month after treatment initiation showing wellexpanded left lung with intercostal tube in situ endseq',
#  'ROCO_01218': 'startseq  single intrauterine fetus of 10 weeks of gestational age with normal right adnexa on 111008 endseq',
#  'ROCO_01220': 'startseq  axial flair image showing hyperintensity of the posterior limb of the right internal capsule endseq',
#  'ROCO_01221': 'startseq  orthopantomogram showing irregular illdefined calcified masses in the lower anterior region endseq',
#  'ROCO_01222': 'startseq  axial plane pelvic mri showed an irregular mass with crenulated margins occupying the urethra and vagina endseq',
#  'ROCO_01223': 'startseq  tip of artery forceps being extracted through an extended right iliac fossa port endseq',
#  'ROCO_01224': 'startseq  a followup case of large retrosternal thyroid goiter who underwent excision developed fever and retrosternal chest pain radiating to the right shoulder ct coronal scan revealed a small hypodense peripherally enhancing collection of 32  33 mm2 size in the right paratracheal region abutting the svc endseq',
#  'ROCO_01227': 'startseq  mature cystic teratoma in a 37yearold womantransvaginal ultrasonography demonstrates a complex echoic mass with a hyperechoic solid portion and posterior shadowing arrows the mass also contains multiple hyperechoic lines and dots endseq',
#  'ROCO_01229': 'startseq  coronal reformatted image of computed tomography performed eleven months after first ct revealed collection of fluid surrounding right adductor muscle red arrow endseq',
#  'ROCO_01230': 'startseq   scrotal ultrasonography after intratesticular injection of cacl 2  a hypoechoic intratesticular area corresponding to a collection of the injected fluid was observed endseq',
#  'ROCO_01231': 'startseq  iopa showing obturation with 11 21 endseq',
#  'ROCO_01232': 'startseq  normal gracilis flap donor site appearances on ct coronal cect showing absence of the normally sited gracilis muscle in the upper thigh arrows in a patient with bilateral gracilis flap reconstruction surgical clips and fat stranding is noted at the donor sites endseq',
#  'ROCO_01233': 'startseq  ct control scan of vb axial endseq',
#  'ROCO_01234': 'startseq  coronal ct scan revealing hyperplasia of the right mandibular condyle medial pterygoid black asterisk lateral pterygoid arrowhead masseter white asterisk and temporalis muscle white arrow endseq',
#  'ROCO_01237': 'startseq  bone resorption from left fossa to condyle in panorama radiograph endseq',
#  'ROCO_01238': 'startseq  occlusion of rca endseq',
#  'ROCO_01239': 'startseq  sagittal t2weighted magnetic resonance imaging showing a large pelvic mass 13  13  11\u2009cm compressing the posterior bladder wall endseq',
#  'ROCO_01240': 'startseq  sagittal magnetic resonance gradient t2 image showing semimembranosus bursa endseq',
#  'ROCO_01241': 'startseq  pelvic radiography radiolucency superimposing the right femoral head can be observed endseq',
#  'ROCO_01242': 'startseq  echocardiogram showing normal ventricular septum endseq',
#  'ROCO_01243': 'startseq  abdominal computed tomography findings a 25mmlong acupuncture needle with high attenuation is seen embedded in the posterior wall of the gastric antrum white arrowhead endseq',
#  'ROCO_01244': 'startseq  another section of the contrastenhanced abdominal ct scan with oral contrast administration revealed an ovoid and welldefined lowdensity tumor in the intussusception endseq',
#  'ROCO_01245': 'startseq  highresolution computed tomography of the thorax endseq',
#  'ROCO_01246': 'startseq  parasternal long axis view showed hypertrabeculation antroseptal and posterior wall endseq',
#  'ROCO_01247': 'startseq   transcatheter arterial embolization sequence as shown in a right hepatic angiography the angiography also demonstrated hypervascular lesions in the cystic tumor endseq',
#  'ROCO_01248': 'startseq  preoperative paranasal sinus view endseq',
#  ...}

# %%
# Save preprocessed captions
np.save(target_path / 'train_captions', train_captions)
np.save(target_path / 'test_captions', test_captions)

# %%
# Get all words used at least once in the captions
def get_full_vocab(data):
    vocab = []
    for caption in data.values():
        captionSplit = caption.split(' ')
        for word in captionSplit:
            vocab.append(word)

    vocab = set(vocab)
    return vocab

# %%
full_vocab = get_full_vocab(train_captions)

len(full_vocab)
# Out:
# 42925

# %%
# Get reduced vocab with only words that have a frequency larger than frequency_limit
def reduce_vocab(data, frequency_limit):
    word_counts = {}
    
    for imageId, caption in data.items():
        for w in caption.split(' '):
            word_counts[w] = word_counts.get(w, 0) + 1

    vocab_reduced = [w for w in word_counts if word_counts[w]>=frequency_limit]

    return vocab_reduced

# %%
reduced_vocab = reduce_vocab(train_captions, FREQUENCY_CUTOFF)
vocab_size = len(reduced_vocab)
variable_params['vocab_size'] = vocab_size + 1
vocab_size + 1
# Out:
# 4471

# %%
# Create word to int correspondence
def get_word_token_correspondence(vocab_reduced):
    
    index2Word = {}
    word2Index = {}

    index = 1
    for w in vocab_reduced:
        word2Index[w] = index
        index2Word[index] = w
        index += 1
        
    return index2Word, word2Index

# %%
index2Word, word2Index = get_word_token_correspondence(reduced_vocab)
print(len(index2Word), len(word2Index))
# Out:
# 4470 4470

# %%
np.save(target_path / 'index2Word', index2Word)
np.save(target_path / 'word2Index', word2Index)

# %%
# Find the maximum caption lenght with the reduced vocabulary, omiting words that do not belong to it 
def get_max_caption_len(data, word2Index):
    
    max_len = 0
    for imageId, caption in data.items():
        seq = [word2Index[word] for word in caption.split(' ') if word in word2Index]
        if len(seq) > max_len:
            max_len = len(seq)

    return max_len

# %%
max_caption_len = get_max_caption_len(train_captions, word2Index)
variable_params['max_caption_len'] = max_caption_len 
max_caption_len
# Out:
# 341

# %%
np.save(target_path / 'variable_params', variable_params)

# %%
import glob
# Get all image paths that will be used for preprocessing later
def get_all_image_paths(img_path):
    images = glob.glob(str(img_path) + '\*.jpg')
    
    images_dict = {}
    for element in images:
        start_index = element.find('ROCO_')
        images_dict[element[start_index:start_index+10]] = element
    
    return images_dict

# %%
#This step is required because the captions may refer to images that are not in this image path
#Takes a minute
train_image_paths = get_all_image_paths(train_image_path)
test_image_paths = get_all_image_paths(test_image_path)

print(len(train_image_paths), len(test_image_paths))
# Out:
# 100 50

# %%
def get_paths_from_set(data, image_paths):

    images = []
    for imageId in data:
        if imageId in image_paths:
            images.append(image_paths[imageId])
            
    return images

# %%
train_image_paths = get_paths_from_set(train_captions, train_image_paths)
test_image_paths = get_paths_from_set(test_captions, test_image_paths)

print(len(train_image_paths), len(test_image_paths))
# Out:
# 100 50

# %%
#This is not required but I was using while writing this to waste less time. Remove after complete
np.save(target_path / 'train_image_paths', train_image_paths)
np.save(target_path / 'test_image_paths', test_image_paths)
