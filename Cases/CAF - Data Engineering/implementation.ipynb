# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Bases de Dados
#
# Nesta etapa vamos carregas as bases disponíveis para trabalharmos.

# %%
df_transacoes = pd.read_json('data/transactions.json')
df_users = pd.read_json('data/users.json')
df_customers = pd.read_json('data/customers.json')

# %%
df_transacoes.head()
# Out:
#                         _id                  tenantId  \
# 0  641336efc5c272ff5d82eb76  64132ef6526eeb8b998e2d3c
# 1  641336efa086e60c7a834713  64132ef6526eeb8b998e2d3c
# 2  641336ef5291e28207a6db05  64132ef6f991a3a1884f2cd0
# 3  641336efbaf638cc19f96b71  64132ef6c9c22c95893e388b
# 4  641336ef24f561f394623973  64132ef68637da8c371cdc09
#
#                      userId                   createdAt  \
# 0  64132e0f48ad8ae93e504d33  2021-01-08T02:24:02 +03:00
# 1  64132e0f1d87f017f64a3c20  2022-02-03T11:17:50 +03:00
# 2  64132e0fb4fade825fdbeed4  2021-09-03T01:40:07 +03:00
# 3  64132e0fac889c7cbd7ebda3  2021-07-25T10:02:11 +03:00
# 4  64132e0f16e8266d4823236c  2022-01-26T11:01:27 +03:00
#
#                     updatedAt favoriteFruit  isFraud  \
# 0  2023-02-08T01:52:32 +03:00    strawberry     True
# 1  2023-01-22T04:27:37 +03:00         apple    False
# 2  2023-02-10T06:17:25 +03:00    strawberry    False
# 3  2023-03-11T02:34:20 +03:00    strawberry     True
# 4  2023-01-14T06:52:42 +03:00    strawberry     True
#
#                                        document
# 0   {'documentType': 'CNH', 'documentUF': 'PA'}
# 1  {'documentType': 'CTPS', 'documentUF': 'PA'}
# 2    {'documentType': 'RG', 'documentUF': 'PA'}
# 3  {'documentType': 'CTPS', 'documentUF': 'BA'}
# 4   {'documentType': 'CNH', 'documentUF': 'RJ'}

# %%
df_users.head()
# Out:
#                         _id             name                      email  \
# 0  64132e0fa1b98612a1366a0a       Lucy Small   gallagherfowler@slax.com
# 1  64132e0f90329937be6d5b65  Alvarado Tanner     kathiekirk@ecratic.com
# 2  64132e0f429adbbe0334ad00    Tucker Wright   mckeebooth@deminimum.com
# 3  64132e0f05e9b1d120893ffe    Oneill Molina  banksgoodwin@fleetmix.com
# 4  64132e0f483bdb42b75e860c  Roberson Miller        ricewebb@biohab.com
#
#                     createdAt                   birthdate
# 0  2020-10-15T08:50:36 +03:00  1990-11-09T04:23:11 +02:00
# 1  2021-03-31T04:35:35 +03:00  1989-07-29T03:39:13 +03:00
# 2  2021-01-12T06:28:25 +03:00  1992-10-11T06:36:20 +03:00
# 3  2021-03-21T10:40:58 +03:00  1981-01-27T07:38:46 +03:00
# 4  2021-12-31T08:11:40 +03:00  1981-05-16T08:02:29 +03:00

# %%
df_customers.head()
# Out:
#                         _id fantasyName            cnpj   status    segment
# 0  64132ef6526eeb8b998e2d3c     Ecratic  38792916000102    Ativo      Banco
# 1  64132ef6f991a3a1884f2cd0   Stockpost  87715692000132  Inativo      Banco
# 2  64132ef6dca9067d51ca1b30     Eschoir  71365876000180  Inativo  Ecommerce
# 3  64132ef6eea665cc154f614a      Verton  62782441000140    Ativo      Banco
# 4  64132ef662f97d5858f87aba   Earthmark  46522418000160    Ativo  Ecommerce

# %% [markdown]
# ## Qualidade dos Dados
#
# Faça uma análise (simples) de qualidade da informação que você recebeu. Não assuma nada nos datasets!

# %%
# Implementação

# %%
df_transacoes.dtypes
# Out:
# _id              object
# tenantId         object
# userId           object
# createdAt        object
# updatedAt        object
# favoriteFruit    object
# isFraud            bool
# document         object
# dtype: object

# %% [markdown]
# Aqui nós vemos que algumas das colunas apresentam tipos "incorretos" de dados, por exemplo, as colunas "createdAt" e "updatedAt" poderiam ser convertidas para um tipo de dados de "datetime" com fuso horário, pois isso pode facilitar algumas das futuras análises. Além disso, a coluna "document" contém dentro dela dicionários, o que talvez não seja a melhor forma de armazenar e acessar tais informações, por isso vamos mudar a sua organização em seguida.

# %%
df_transacoes.isna().sum()
# Out:
# _id              0
# tenantId         0
# userId           0
# createdAt        0
# updatedAt        0
# favoriteFruit    0
# isFraud          0
# document         0
# dtype: int64

# %% [markdown]
# Por outro lado, a base não apresenta "missing values" em nenhuma das colunas, o que é positivo.

# %%
print('numero total de transacoes = ', len(df_transacoes))
# Out:
# numero total de transacoes =  10002

# %%
print(df_users.dtypes)
print('\n',df_users.isna().sum())
print('\n numero total de usuarios = ', len(df_users))
# Out:
# _id          object
# name         object
# email        object
# createdAt    object
# birthdate    object
# dtype: object
#
#  _id          0
# name         0
# email        0
# createdAt    0
# birthdate    0
# dtype: int64
#
#  numero total de usuarios =  100

# %% [markdown]
# Nessa tabela temos o mesmo problema relativo às datas mas novamente não temos valores não encontrados.

# %%
print(df_customers.dtypes)
print('\n',df_customers.isna().sum())
print('\n numero total de customers =  ', len(df_customers))
# Out:
# _id            object
# fantasyName    object
# cnpj            int64
# status         object
# segment        object
# dtype: object
#
#  _id            0
# fantasyName    0
# cnpj           0
# status         0
# segment        0
# dtype: int64
#
#  numero total de customers =   10

# %% [markdown]
# Finalmente, nessa tabela parece que temos uma boa qualidade no geral, porém talvez fosse melhor renomear a coluna "status" para "ativo" e mudar o tipo de dados para booleanos, isso pode ser mais eficiente para análises de larga escala. Por fim, dependendo da aplicação, por examplo se fosse para utilizar esse dados em modelos de machine learning, a coluna "segment" poderia ser convertida em identificadores númericos que pudessem ser inputados no modelo.

# %% [markdown]
# # Modelagem
# Implemente os cruzamentos e modelagem correta nas bases, de acordo com o `README.md` disponível.
#
# Aqui, será verificada sua capacidade de entender, modelar e disponibilizar dados de modo que seja simples, limpo e eficiente. Você pode escolher qualquer estratégia que desejar (normalização, dimensionamento, fato, etc).

# %%
# Implementação

# %%
# Primeiro faremos alguns dos tratamentos citados na etapa anterior.

df_transacoes['createdAt'] = pd.to_datetime(df_transacoes['createdAt'])
df_transacoes['updatedAt'] = pd.to_datetime(df_transacoes['updatedAt'])

# Fazemos a mudança na coluna "document" também como descrita, removendo os dicionários
df_transacoes = df_transacoes.drop('document', axis = 1).assign(**df_transacoes['document'].dropna().apply(pd.Series))
df_transacoes.head()

df_transacoes
# Out:
#                             _id                  tenantId  \
# 0      641336efc5c272ff5d82eb76  64132ef6526eeb8b998e2d3c
# 1      641336efa086e60c7a834713  64132ef6526eeb8b998e2d3c
# 2      641336ef5291e28207a6db05  64132ef6f991a3a1884f2cd0
# 3      641336efbaf638cc19f96b71  64132ef6c9c22c95893e388b
# 4      641336ef24f561f394623973  64132ef68637da8c371cdc09
# ...                         ...                       ...
# 9997   641336ef434f4da45e00379f  64132ef6ccd2d35a83c3544a
# 9998   641336efa0febbc18ae452f3  64132ef6526eeb8b998e2d3c
# 9999   641336efecd20d71ae58208f  64132ef68637da8c371cdc09
# 10000  641336ef7cc5c59939e34f34  64132ef6eea665cc154f614a
# 10001  641336ef03c98db9e2995bc3  64132ef6f54b06e1ffb65fba
#
#                          userId                 createdAt  \
# 0      64132e0f48ad8ae93e504d33 2021-01-08 02:24:02+03:00
# 1      64132e0f1d87f017f64a3c20 2022-02-03 11:17:50+03:00
# 2      64132e0fb4fade825fdbeed4 2021-09-03 01:40:07+03:00
# 3      64132e0fac889c7cbd7ebda3 2021-07-25 10:02:11+03:00
# 4      64132e0f16e8266d4823236c 2022-01-26 11:01:27+03:00
# ...                         ...                       ...
# 9997   64132e0f9647ed73a005c271 2022-01-04 01:26:08+03:00
# 9998   64132e0f9417d076f85b8f61 2022-10-28 05:01:20+03:00
# 9999   64132e0f29d8b74c6b1cb514 2022-12-30 08:19:19+03:00
# 10000  64132e0fe8e5688a81c56b8a 2022-11-02 09:01:38+03:00
# 10001  64132e0fd3bdca816cd9ac2f 2021-07-17 08:50:47+03:00
#
#                       updatedAt favoriteFruit  isFraud documentType documentUF
# 0     2023-02-08 01:52:32+03:00    strawberry     True          CNH         PA
# 1     2023-01-22 04:27:37+03:00         apple    False         CTPS         PA
# 2     2023-02-10 06:17:25+03:00    strawberry    False           RG         PA
# 3     2023-03-11 02:34:20+03:00    strawberry     True         CTPS         BA
# 4     2023-01-14 06:52:42+03:00    strawberry     True          CNH         RJ
# ...                         ...           ...      ...          ...        ...
# 9997  2023-02-16 11:58:18+03:00        banana     True          CNH         BA
# 9998  2023-03-15 06:59:41+03:00    strawberry    False          CNH         MT
# 9999  2023-02-11 10:13:33+03:00        banana    False           RG         RJ
# 10000 2023-01-12 10:05:32+03:00         apple    False           RG         PA
# 10001 2023-02-01 12:36:04+03:00         apple    False           RG         MT
#
# [10002 rows x 9 columns]

# %%
# Agora que fizemos essa transformação precisamos verificar novamente se existem valores perdidos
df_transacoes.isna().sum()

# E vemos que agora existem valores perdidos
# Out:
# _id              0
# tenantId         0
# userId           0
# createdAt        0
# updatedAt        0
# favoriteFruit    0
# isFraud          0
# documentType     3
# documentUF       2
# dtype: int64

# %%
df_users['createdAt'] = pd.to_datetime(df_users['createdAt'])
df_users['birthdate'] = pd.to_datetime(df_users['birthdate'], utc = True)
df_users.dtypes
# Out:
# _id                                         object
# name                                        object
# email                                       object
# createdAt    datetime64[ns, pytz.FixedOffset(180)]
# birthdate                      datetime64[ns, UTC]
# dtype: object

# %%
df_customers['status'] = (df_customers['status'] == 'Ativo')
df_customers.rename(columns = {'status': 'ativo'})
# Out:
#                         _id fantasyName            cnpj  ativo    segment
# 0  64132ef6526eeb8b998e2d3c     Ecratic  38792916000102   True      Banco
# 1  64132ef6f991a3a1884f2cd0   Stockpost  87715692000132  False      Banco
# 2  64132ef6dca9067d51ca1b30     Eschoir  71365876000180  False  Ecommerce
# 3  64132ef6eea665cc154f614a      Verton  62782441000140   True      Banco
# 4  64132ef662f97d5858f87aba   Earthmark  46522418000160   True  Ecommerce
# 5  64132ef6f54b06e1ffb65fba     Tingles  84854134000160   True      Banco
# 6  64132ef64f72ae4d32dc3535      Zytrax  67804098000100  False   Serviços
# 7  64132ef6ccd2d35a83c3544a    Exospace  35354484000151   True      Banco
# 8  64132ef6c9c22c95893e388b       Bisba  35166986000159   True      Banco
# 9  64132ef68637da8c371cdc09        Caxt  23114879000106   True      Banco

# %%
# Agora vamos usar a estratégia de dimensionamento-fato (levemente snowflake) para modelar a base de dados.
# Para isso, teremos 4 tabelas dimensão (data, user, customer e document) e uma tabela fato (transações).

# Data
start_date = np.min([np.min(df_users['birthdate']), np.min(df_users['createdAt']), np.min(df_transacoes['createdAt']), np.min(df_transacoes['updatedAt'])])
end_date = np.max([np.max(df_users['birthdate']), np.max(df_users['createdAt']), np.max(df_transacoes['createdAt']), np.max(df_transacoes['updatedAt'])])

dim_date = pd.DataFrame()
date_range = pd.date_range(start_date.replace(tzinfo=None).date(), end_date.replace(tzinfo=None).date())#.to_series()
dim_date['date'] = date_range
dim_date['year'] = dim_date['date'].dt.year
dim_date['month'] = dim_date['date'].dt.month
dim_date['day'] = dim_date['date'].dt.day
dim_date = dim_date.reset_index().rename(columns={'index':'dateId'})
dim_date
# Out:
#        dateId       date  year  month  day
# 0           0 1980-05-19  1980      5   19
# 1           1 1980-05-20  1980      5   20
# 2           2 1980-05-21  1980      5   21
# 3           3 1980-05-22  1980      5   22
# 4           4 1980-05-23  1980      5   23
# ...       ...        ...   ...    ...  ...
# 15637   15637 2023-03-12  2023      3   12
# 15638   15638 2023-03-13  2023      3   13
# 15639   15639 2023-03-14  2023      3   14
# 15640   15640 2023-03-15  2023      3   15
# 15641   15641 2023-03-16  2023      3   16
#
# [15642 rows x 5 columns]

# %% [markdown]
# É importante notar que nós removemos as informações com granularidade menor que dia nessa tabela,
# como horas e fuso horário. Isso foi feito porque senão a tabela seria muito grande e ela tem como objetivo fazer queries mais granulosas como as analises mensais que faremos a seguir, e então não precisamos de granularidade de segundos, por exemplo.
#
# Além disso, para garantir que as informações não são perdidas para sempre, manteremos essas informações nas tabelas originais. Isso pode ser ineficiente em termos de espaço de armazenagem e deve ser discutido, mas sem mais informações dos objetivos dessas tabelas e como elas serão usadas pelos analistas, é importante manter essa informação disponível para analises mais finas.

# %%
# E criar a coluna de id na tabela fato

fato_transacoes = df_transacoes.copy()

fato_transacoes['tmpCreatedAt'] = fato_transacoes['createdAt'].dt.floor('d').dt.tz_localize(None)
fato_transacoes = pd.merge(fato_transacoes, dim_date[['dateId', 'date']], left_on = 'tmpCreatedAt', right_on = 'date', how = 'left')
fato_transacoes.drop(columns = ['date', 'tmpCreatedAt'], inplace = True)
fato_transacoes.rename(columns = {'dateId': 'dateCreatedId'}, inplace = True)


fato_transacoes['tmpUpdatedAt'] = fato_transacoes['updatedAt'].dt.floor('d').dt.tz_localize(None)
fato_transacoes = pd.merge(fato_transacoes, dim_date[['dateId', 'date']], left_on = 'tmpUpdatedAt', right_on = 'date', how = 'left')
fato_transacoes.drop(columns = ['date', 'tmpUpdatedAt'], inplace = True)
fato_transacoes.rename(columns = {'dateId': 'dateUpdatedId'}, inplace = True)

fato_transacoes
# Out:
#                             _id                  tenantId  \
# 0      641336efc5c272ff5d82eb76  64132ef6526eeb8b998e2d3c
# 1      641336efa086e60c7a834713  64132ef6526eeb8b998e2d3c
# 2      641336ef5291e28207a6db05  64132ef6f991a3a1884f2cd0
# 3      641336efbaf638cc19f96b71  64132ef6c9c22c95893e388b
# 4      641336ef24f561f394623973  64132ef68637da8c371cdc09
# ...                         ...                       ...
# 9997   641336ef434f4da45e00379f  64132ef6ccd2d35a83c3544a
# 9998   641336efa0febbc18ae452f3  64132ef6526eeb8b998e2d3c
# 9999   641336efecd20d71ae58208f  64132ef68637da8c371cdc09
# 10000  641336ef7cc5c59939e34f34  64132ef6eea665cc154f614a
# 10001  641336ef03c98db9e2995bc3  64132ef6f54b06e1ffb65fba
#
#                          userId                 createdAt  \
# 0      64132e0f48ad8ae93e504d33 2021-01-08 02:24:02+03:00
# 1      64132e0f1d87f017f64a3c20 2022-02-03 11:17:50+03:00
# 2      64132e0fb4fade825fdbeed4 2021-09-03 01:40:07+03:00
# 3      64132e0fac889c7cbd7ebda3 2021-07-25 10:02:11+03:00
# 4      64132e0f16e8266d4823236c 2022-01-26 11:01:27+03:00
# ...                         ...                       ...
# 9997   64132e0f9647ed73a005c271 2022-01-04 01:26:08+03:00
# 9998   64132e0f9417d076f85b8f61 2022-10-28 05:01:20+03:00
# 9999   64132e0f29d8b74c6b1cb514 2022-12-30 08:19:19+03:00
# 10000  64132e0fe8e5688a81c56b8a 2022-11-02 09:01:38+03:00
# 10001  64132e0fd3bdca816cd9ac2f 2021-07-17 08:50:47+03:00
#
#                       updatedAt favoriteFruit  isFraud documentType  \
# 0     2023-02-08 01:52:32+03:00    strawberry     True          CNH
# 1     2023-01-22 04:27:37+03:00         apple    False         CTPS
# 2     2023-02-10 06:17:25+03:00    strawberry    False           RG
# 3     2023-03-11 02:34:20+03:00    strawberry     True         CTPS
# 4     2023-01-14 06:52:42+03:00    strawberry     True          CNH
# ...                         ...           ...      ...          ...
# 9997  2023-02-16 11:58:18+03:00        banana     True          CNH
# 9998  2023-03-15 06:59:41+03:00    strawberry    False          CNH
# 9999  2023-02-11 10:13:33+03:00        banana    False           RG
# 10000 2023-01-12 10:05:32+03:00         apple    False           RG
# 10001 2023-02-01 12:36:04+03:00         apple    False           RG
#
#       documentUF  dateCreatedId  dateUpdatedId
# 0             PA          14844          15605
# 1             PA          15235          15588
# 2             PA          15082          15607
# 3             BA          15042          15636
# 4             RJ          15227          15580
# ...          ...            ...            ...
# 9997          BA          15205          15613
# 9998          MT          15502          15640
# 9999          RJ          15565          15608
# 10000         PA          15507          15578
# 10001         MT          15034          15598
#
# [10002 rows x 11 columns]

# %%
# E na tabela users
dim_users = df_users.copy() 
dim_users['tmpCreatedAt'] = dim_users['createdAt'].dt.floor('d').dt.tz_localize(None)
dim_users = pd.merge(dim_users, dim_date[['dateId', 'date']], left_on = 'tmpCreatedAt', right_on = 'date', how = 'left')
dim_users.drop(columns = ['date', 'tmpCreatedAt'], inplace = True)
dim_users.rename(columns = {'dateId': 'dateCreatedId'}, inplace = True)


dim_users['tmpBirthdate'] = dim_users['birthdate'].dt.floor('d').dt.tz_localize(None)
dim_users = pd.merge(dim_users, dim_date[['dateId', 'date']], left_on = 'tmpBirthdate', right_on = 'date', how = 'left')
dim_users.drop(columns = ['date', 'tmpBirthdate'], inplace = True)
dim_users.rename(columns = {'dateId': 'dateUpdatedId'}, inplace = True)

cols = dim_users.columns.tolist()
cols = cols[-2:] + cols[:-2]
dim_users = dim_users[cols]

dim_users
# Out:
#     dateCreatedId  dateUpdatedId                       _id  \
# 0           14759           3826  64132e0fa1b98612a1366a0a
# 1           14926           3358  64132e0f90329937be6d5b65
# 2           14848           4528  64132e0f429adbbe0334ad00
# 3           14916            253  64132e0f05e9b1d120893ffe
# 4           15201            362  64132e0f483bdb42b75e860c
# ..            ...            ...                       ...
# 95          15567           2390  64132e0fd0fd03a2161eade3
# 96          14683           1860  64132e0f5db21511f29bd2c3
# 97          14664           6358  64132e0f49625262850d71ab
# 98          14795           4583  64132e0f1eeec2acd297c0e9
# 99          14719           4768  64132e0ff769e21f3707d966
#
#                   name                          email  \
# 0           Lucy Small       gallagherfowler@slax.com
# 1      Alvarado Tanner         kathiekirk@ecratic.com
# 2        Tucker Wright       mckeebooth@deminimum.com
# 3        Oneill Molina      banksgoodwin@fleetmix.com
# 4      Roberson Miller            ricewebb@biohab.com
# ..                 ...                            ...
# 95  Henrietta Bradford        nonaharding@ezentia.com
# 96     Kristen Beasley    mariastephenson@slambda.com
# 97       Katrina Welch         tishaclark@isosure.com
# 98       Mayer Spencer  montgomerydennis@buzzness.com
# 99   Lakisha Maldonado      rachellelopez@comtour.com
#
#                    createdAt                 birthdate
# 0  2020-10-15 08:50:36+03:00 1990-11-09 02:23:11+00:00
# 1  2021-03-31 04:35:35+03:00 1989-07-29 00:39:13+00:00
# 2  2021-01-12 06:28:25+03:00 1992-10-11 03:36:20+00:00
# 3  2021-03-21 10:40:58+03:00 1981-01-27 04:38:46+00:00
# 4  2021-12-31 08:11:40+03:00 1981-05-16 05:02:29+00:00
# ..                       ...                       ...
# 95 2023-01-01 08:46:30+03:00 1986-12-04 05:23:46+00:00
# 96 2020-07-31 09:28:58+03:00 1985-06-22 05:54:52+00:00
# 97 2020-07-12 01:34:15+03:00 1997-10-15 08:23:49+00:00
# 98 2020-11-20 12:08:03+03:00 1992-12-05 04:40:09+00:00
# 99 2020-09-05 01:52:29+03:00 1993-06-08 02:52:14+00:00
#
# [100 rows x 7 columns]

# %%
# Criamos a tabela dimensão de documentos
dim_document = df_transacoes[['documentType', 'documentUF']]
dim_document = dim_document.drop_duplicates().reset_index().rename(columns={'index':'documentId'})

dim_document
# Out:
#     documentId documentType documentUF
# 0            0          CNH         PA
# 1            1         CTPS         PA
# 2            2           RG         PA
# 3            3         CTPS         BA
# 4            4          CNH         RJ
# 5            5          CNH         RS
# 6            6          CNH         SP
# 7            9         CTPS         RJ
# 8           10          CNH         BA
# 9           13         CTPS         RS
# 10          15          CNH         MT
# 11          21           RG         SP
# 12          22         CTPS         MT
# 13          29           RG         RJ
# 14          33           RG         MT
# 15          34           RG         BA
# 16          39         CTPS         SP
# 17          63           RG         RS
# 18        3721          NaN         PA
# 19        5212          NaN         RJ
# 20        5213          NaN         BA
# 21        5215           RG        NaN
# 22        5216          CNH        NaN

# %%
# E criar a coluna de ID na tabela fato

fato_transacoes = pd.merge(fato_transacoes, dim_document, on = ['documentType', 'documentUF'], how = 'left')
fato_transacoes.drop(columns = ['documentType', 'documentUF'], inplace = True)
fato_transacoes.rename(columns = {'index': 'documentId'}, inplace = True)

cols = fato_transacoes.columns.tolist()
cols = cols[-3:] + cols[:-3]
fato_transacoes = fato_transacoes[cols]
fato_transacoes.fillna('-', inplace = True)
dim_document.fillna('-', inplace = True)

fato_transacoes
# Out:
#        dateCreatedId  dateUpdatedId  documentId                       _id  \
# 0              14844          15605           0  641336efc5c272ff5d82eb76
# 1              15235          15588           1  641336efa086e60c7a834713
# 2              15082          15607           2  641336ef5291e28207a6db05
# 3              15042          15636           3  641336efbaf638cc19f96b71
# 4              15227          15580           4  641336ef24f561f394623973
# ...              ...            ...         ...                       ...
# 9997           15205          15613          10  641336ef434f4da45e00379f
# 9998           15502          15640          15  641336efa0febbc18ae452f3
# 9999           15565          15608          29  641336efecd20d71ae58208f
# 10000          15507          15578           2  641336ef7cc5c59939e34f34
# 10001          15034          15598          33  641336ef03c98db9e2995bc3
#
#                        tenantId                    userId  \
# 0      64132ef6526eeb8b998e2d3c  64132e0f48ad8ae93e504d33
# 1      64132ef6526eeb8b998e2d3c  64132e0f1d87f017f64a3c20
# 2      64132ef6f991a3a1884f2cd0  64132e0fb4fade825fdbeed4
# 3      64132ef6c9c22c95893e388b  64132e0fac889c7cbd7ebda3
# 4      64132ef68637da8c371cdc09  64132e0f16e8266d4823236c
# ...                         ...                       ...
# 9997   64132ef6ccd2d35a83c3544a  64132e0f9647ed73a005c271
# 9998   64132ef6526eeb8b998e2d3c  64132e0f9417d076f85b8f61
# 9999   64132ef68637da8c371cdc09  64132e0f29d8b74c6b1cb514
# 10000  64132ef6eea665cc154f614a  64132e0fe8e5688a81c56b8a
# 10001  64132ef6f54b06e1ffb65fba  64132e0fd3bdca816cd9ac2f
#
#                       createdAt                 updatedAt favoriteFruit  \
# 0     2021-01-08 02:24:02+03:00 2023-02-08 01:52:32+03:00    strawberry
# 1     2022-02-03 11:17:50+03:00 2023-01-22 04:27:37+03:00         apple
# 2     2021-09-03 01:40:07+03:00 2023-02-10 06:17:25+03:00    strawberry
# 3     2021-07-25 10:02:11+03:00 2023-03-11 02:34:20+03:00    strawberry
# 4     2022-01-26 11:01:27+03:00 2023-01-14 06:52:42+03:00    strawberry
# ...                         ...                       ...           ...
# 9997  2022-01-04 01:26:08+03:00 2023-02-16 11:58:18+03:00        banana
# 9998  2022-10-28 05:01:20+03:00 2023-03-15 06:59:41+03:00    strawberry
# 9999  2022-12-30 08:19:19+03:00 2023-02-11 10:13:33+03:00        banana
# 10000 2022-11-02 09:01:38+03:00 2023-01-12 10:05:32+03:00         apple
# 10001 2021-07-17 08:50:47+03:00 2023-02-01 12:36:04+03:00         apple
#
#        isFraud
# 0         True
# 1        False
# 2        False
# 3         True
# 4         True
# ...        ...
# 9997      True
# 9998     False
# 9999     False
# 10000    False
# 10001    False
#
# [10002 rows x 10 columns]

# %%
# renomear as colunas das tabelas para padronizar as chaves primarias

dim_date.rename(columns = {'dateId': '_id'}, inplace = True)
dim_document.rename(columns = {'documentId': '_id'}, inplace = True)

# %%
import mysql.connector
from mysql.connector import errorcode

# %%
config = {
   'user': 'root',
   'password': 'Ninkelas2.',
   'host': 'localhost',
   'database': 'transactions',
   'raise_on_warnings': True
}

connection = mysql.connector.connect(
  host='localhost',
  user='root',
  password='#####'
)

database_name = 'transactions'
cursor = connection.cursor()

cursor.execute("DROP DATABASE IF EXISTS {} ".format(database_name))
cursor.execute("CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database_name))

connection.commit()

# %%
TABLES = {}
TABLES['documents'] = """CREATE TABLE dimDocuments (
                _id INT NOT NULL ,
                documentType VARCHAR(10),
                documentUF VARCHAR(10),
                PRIMARY KEY (_id)
            )"""

TABLES['dates'] = """CREATE TABLE dimDate (
                _id INT NOT NULL ,
                date DATE,
                year INT,
                month INT,
                day INT,
                PRIMARY KEY (_id)
            )"""

TABLES['customers'] = """CREATE TABLE dimCustomers (
                _id VARCHAR(255),
                fantasyName VARCHAR(255),
                cnpj VARCHAR(14),
                status VARCHAR(255),
                segment VARCHAR(255),
                PRIMARY KEY (_id)
            )"""

TABLES['users'] = """CREATE TABLE dimUsers (
                dateCreatedId INT NOT NULL,
                dateUpdatedId INT NOT NULL,
                _id VARCHAR(255),
                name VARCHAR(255),
                email VARCHAR(255),
                createdAt TIMESTAMP,
                birthdate TIMESTAMP,
                PRIMARY KEY (_id),
                FOREIGN KEY (dateCreatedId) REFERENCES dimDate(_id),
                FOREIGN KEY (dateUpdatedId) REFERENCES dimDate(_id)
            )"""

TABLES['fact'] = """CREATE TABLE factTransactions (
                dateCreatedId INT NOT NULL,
                dateUpdatedId INT NOT NULL,
                documentId INT NOT NULL,
                _id VARCHAR(255),
                tenantId VARCHAR(255),
                userId VARCHAR(255),
                createdAt TIMESTAMP,
                updatedAt TIMESTAMP,
                favoriteFruit VARCHAR(255),
                isFraud BOOLEAN,
                PRIMARY KEY (_id, updatedAt),
                FOREIGN KEY (dateCreatedId) REFERENCES dimDate(_id),
                FOREIGN KEY (dateUpdatedId) REFERENCES dimDate(_id),
                FOREIGN KEY (documentId) REFERENCES dimDocuments(_id),
                FOREIGN KEY (tenantId) REFERENCES dimCustomers(_id),
                FOREIGN KEY (userId) REFERENCES dimUsers(_id)
            )"""

# %%
cnx = mysql.connector.connect(**config)
cursor = cnx.cursor()

try:
    cnx.database = config['database']
except mysql.connector.Error as err:
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor)
        cnx.database = config['database']
    else:
        print(err)
        exit(1)

for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")

cursor.close()
cnx.close()
# Out:
# Creating table documents: OK
# Creating table dates: OK
# Creating table customers: OK
# Creating table users: OK
# Creating table fact: OK

# %%
cnx = mysql.connector.connect(**config)
cursor = cnx.cursor()

# Insert data into dimDocuments table
add_data_query = ("INSERT INTO dimDocuments "
                  "(_id, documentType, documentUF) "
                  "VALUES (%s, %s, %s)")
data = [tuple(x) for x in dim_document.to_numpy()]
cursor.executemany(add_data_query, data)

# %%
add_data_query = ("INSERT INTO dimDate "
                  "(_id, date, year, month, day) "
                  "VALUES (%s, %s, %s, %s, %s)")
data = [tuple(x) for x in dim_date.to_numpy()]
cursor.executemany(add_data_query, data)

# %%
add_data_query = ("INSERT INTO dimUsers "
                  "(dateCreatedId, dateUpdatedId, _id, name, email, createdAt, birthdate) "
                  "VALUES (%s, %s, %s, %s, %s, %s, %s)")
data = [tuple(x) for x in dim_users.to_numpy()]
cursor.executemany(add_data_query, data)

# %%
add_data_query = ("INSERT INTO dimCustomers "
                  "(_id, fantasyName, cnpj, status, segment) "
                  "VALUES (%s, %s, %s, %s, %s)")
data = [tuple(x) for x in df_customers.to_numpy()]
cursor.executemany(add_data_query, data)

# %%
add_data_query = ("INSERT INTO factTransactions "
                  "(dateCreatedId, dateUpdatedId, documentId, _id, tenantId, userId, createdAt, UpdatedAt, favoriteFruit, isFraud) "
                  "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)")
data = [tuple(x) for x in fato_transacoes.to_numpy()]
cursor.executemany(add_data_query, data)

# %% [markdown]
# Usando a estratégia de dimensionamento-fato, temos 5 tabelas diferentes, 4 tabelas de dimensão e uma tabela fato. Isso nos permite criar facilmente queries eficientes que dependem, por exemplo, do tipo de documentação usada para realizar a transação ou do mês em que a transação foi realizada.
#
# É importante notar que usamos uma esquema de estrela na nossa estratégia, o que implica que nossas tabelas não necessariamente estão normalizadas, mas discutiremos essa escolha na próxima seção.
#
# Por fim, implementamos um banco de dados de MySQL com as relações necessárias entre as tabelas considerando suas chaves primárias e estrangeiras.

# %% [markdown]
# # Disponibilização e Processamento
#
# Agora que você já modelou as bases, discuta sobre as estratégias de armazenamento.
#
# 1. Como você disponibilizaria estas bases no data lake (em S3)? Não precisa enviar o arquivo, apenas discuta.
# 2. Qual formato de arquivo você escolheria para persistir estas bases? Por que?
# 3. Você prefere bases normalizadas ou desnormalizadas? Discuta os pontos positivos e negativos de cada um.
#
# Persista sua modelagem final conforme suas opções e responda as próximas perguntas a partir dela. Não esqueça de desalocar os dataframes antigos!

# %%
# Implementação

# %% [markdown]
# 1. Existem várias maneiras de disponibilizar as bases no data lake, como simplesmente salvar os arquivos localmente e usar a interface do S3 na web para disponibilizar os arquivos no data lake. Porém essa não é a maneira mais eficiente, na minha opinião, eu usaria a SDK da Amazon para Python, chamada boto3 e enviaria os arquivos dessa forma.

# %%
# O código poderia ser algo dessa natureza:

'''def uploadDirectory(path,bucketname):
    for root,dirs,files in os.walk(path):
        for file in files:
            s3C.upload_file(os.path.join(root,file),bucketname,file)'''

# Considerando que as tabelas finais após a modelagem se encontram todas em uma pasta específica
# Out:
# 'def uploadDirectory(path,bucketname):\n    for root,dirs,files in os.walk(path):\n        for file in files:\n            s3C.upload_file(os.path.join(root,file),bucketname,file)'

# %% [markdown]
# 2 - A escolha de que formato de arquivo deve ser usado depende bastante de qual a será o uso dessas tabelas após o upload para o S3. Por exemplo, se for para essas tabelas serem usadas para analistas que utilizam excel, seria ideal salvar esses dados com um formato .csv para facilitar o acesso desses arquivos aos usuários finais.
#
# Por outro lado, se esses dados forem ser utilizados para popular tabelas do Redshift, então outras possibilidades se abrem, por exemplo podemos salvar os dados em json ou parquet e além disso podemos zippar os arquivos, dado que o Redshift é capaz de abrir esses tipos de arquivo com facilidade além dos tipos character-separated values e .csv. O parquet seria superior nesse caso por causa da maior velocidade de leitura e da maior compressão dos dados.
#
# Considerando isso, e meu entendimento dos objetivos atuais da caf, eu optaria por salvar as tabelas em Parquet.

# %% [markdown]
# 3 - Novamente, a escolha de bases normalizadas ou desnormalizadas é dependente do tipo de uso que a base terá. Por exemplo, bases normalizadas têm maior velocidade na inclusão, atualização e deleção de dados, porém bases desnormalizadas têm maior velocidade na leitura dos dados. Isso significa que se a base for usada de forma que um grande número de leituras seja executado, pode ser melhor que usemos uma base desnormalizada. Por outro lado, se essa base for lida infrequentemente mas atualizada frequentemente, uma base normalizada deve ser melhor.
#
# Além disso, bases normalizadas tem maior eficiência em termos de memória, mesmo apresentando um número maior de tabelas, devido à redução da redundância nos dados. Porém isso também implica que as queries em bases normalizadas tendem a ser mais complexas do que àquelas feitas em bases desnormalizadas.
#
# A minha preferência é por bases desnormalizadas pois eu considero que é mais intuitivo acessar e realizar queries nesse tipo de base, facilitando o processo de levantamento de hipóteses e de solução de problemas, agilizando o desenvolvimento. Além disso, temos maior velocidade de resposta das queries de leitura. Porém, em casos específicos, a base normalizada deve ser considerada e apresenta vantagens significativas, como redução de custos por maior eficiência no armazenamento.

# %%
# Salvando as tabelas finais usando parquet e zip
dim_date.to_parquet('PersistentData/dimDate.parquet.gzip', compression='gzip')
dim_users.to_parquet('PersistentData/dimUsers.parquet.gzip', compression='gzip')
df_customers.to_parquet('PersistentData/dimCustomers.parquet.gzip', compression='gzip')
dim_document.to_parquet('PersistentData/dimDocument.parquet.gzip', compression='gzip')
fato_transacoes.to_parquet('PersistentData/FactTransactions.parquet.gzip', compression='gzip')

del df_customers
del df_transacoes
del df_users
del dim_users
del dim_date
del dim_document
del fato_transacoes

# %% [markdown]
# # Perguntas

# %% [markdown]
# Agora com a sua modelagem pronta, responda as seguintes perguntas utilizando SQL:
#
# ### Obrigatórias
# 1. Qual a média de tentativas de fraudes por mês (quantidade)?
# 2. Quais são as UFs com o maior percentual de tentativa de fraude?
# 3. Em quais meses do ano o percentual de tentativa de fraude foi maior e em quais foram menores?
# 4. Quais são os 10 clientes com maior quantidade de transações?
# 5. Qual a idade média dos usuários?
# 6. Qual documento é mais utilizado pelos usuários?
#
#
# ### Desafio Extra
# 1. Há na base transações iguais mas com data de atualização diferente (houve modificação na transação e por isso ela ganhou um novo registro). Faça um select que retorne sempre a versão mais recente das transações, permitindo assim a visualização das informações mais recentes

# %%
# 1 usando SQL
query = ("""SELECT dimDate.month, SUM(factTransactions.isFraud) AS sum
            FROM factTransactions
            JOIN dimDate ON factTransactions.dateCreatedId = dimDate._id
            GROUP BY dimDate.month
            ORDER BY dimDate.month""")

cursor.execute(query)
query = cursor.fetchall()
query
# Out:
# [(1, Decimal('440')),
#  (2, Decimal('387')),
#  (3, Decimal('413')),
#  (4, Decimal('435')),
#  (5, Decimal('434')),
#  (6, Decimal('428')),
#  (7, Decimal('398')),
#  (8, Decimal('448')),
#  (9, Decimal('423')),
#  (10, Decimal('418')),
#  (11, Decimal('415')),
#  (12, Decimal('405'))]

# %%
# 2 usando sql
query = ("""SELECT dimDocuments.documentUF, AVG(factTransactions.isFraud) AS mean_value
            FROM factTransactions
            JOIN dimDocuments ON factTransactions.documentId = dimDocuments._id
            GROUP BY dimDocuments.documentUF
            """)

cursor.execute(query)
query = cursor.fetchall()
query
# Out:
# [('PA', Decimal('0.5066')),
#  ('BA', Decimal('0.5065')),
#  ('RJ', Decimal('0.5108')),
#  ('RS', Decimal('0.4834')),
#  ('SP', Decimal('0.5117')),
#  ('MT', Decimal('0.5060')),
#  ('-', Decimal('1.0000'))]

# %%
# 3 usando sql
query = ("""SELECT dimDate.month, AVG(factTransactions.isFraud) AS mean_month
            FROM factTransactions
            JOIN dimDate ON factTransactions.dateCreatedId = dimDate._id
            GROUP BY dimDate.month
            ORDER BY mean_month DESC""")

cursor.execute(query)
query = cursor.fetchall()
query
# Out:
# [(10, Decimal('0.5218')),
#  (8, Decimal('0.5209')),
#  (4, Decimal('0.5160')),
#  (2, Decimal('0.5146')),
#  (9, Decimal('0.5084')),
#  (6, Decimal('0.5065')),
#  (5, Decimal('0.5041')),
#  (3, Decimal('0.5018')),
#  (11, Decimal('0.5018')),
#  (1, Decimal('0.4911')),
#  (12, Decimal('0.4874')),
#  (7, Decimal('0.4789'))]

# %%
# 4 usando SQL. Assumindo que o cliente é o usuário apesar de a tradução mais precisa ser o customer, isso
# porque só existem apenas 10 customers então determinar o top 10 seria equivalente a determinar tudo.
query = ("""SELECT dimUsers.name, COUNT(*) AS count
            FROM factTransactions
            JOIN dimUsers ON factTransactions.userId = dimUsers._id
            GROUP BY dimUsers.name
            ORDER BY count DESC limit 10""")

cursor.execute(query)
query = cursor.fetchall()
query
# Out:
# [('Morin Nolan', 127),
#  ('Harrington Wilkerson', 125),
#  ('Audrey Maynard', 119),
#  ('Horn Larsen', 118),
#  ('Nell Dyer', 118),
#  ('Mari Willis', 118),
#  ('Susanna Padilla', 118),
#  ('Huber Hernandez', 117),
#  ('Chelsea Ortiz', 116),
#  ('Bernadine Vargas', 116)]

# %%
# 4 usando SQL. E então fazendo para os customers.
query = ("""SELECT dimCustomers.fantasyName, COUNT(*) AS count
            FROM factTransactions
            JOIN dimCustomers ON factTransactions.tenantId = dimCustomers._id
            GROUP BY dimCustomers.fantasyName
            ORDER BY count DESC limit 10""")

cursor.execute(query)
query = cursor.fetchall()
query
# Out:
# [('Tingles', 1062),
#  ('Caxt', 1018),
#  ('Earthmark', 1017),
#  ('Stockpost', 1015),
#  ('Ecratic', 1009),
#  ('Eschoir', 1000),
#  ('Verton', 981),
#  ('Bisba', 972),
#  ('Zytrax', 964),
#  ('Exospace', 964)]

# %%
# 5 usando SQL.
query = ("""SELECT AVG(DATEDIFF(CURRENT_DATE, birthdate) / 365) AS average_age
            FROM dimUsers""")

cursor.execute(query)
query = cursor.fetchall()
query
# Out:
# [(Decimal('34.02183562'),)]

# %%
# 6 usando SQL.
query = ("""SELECT dimDocuments.documentType, COUNT(*) AS count
            FROM factTransactions
            JOIN dimDocuments ON factTransactions.documentId = dimDocuments._id
            GROUP BY dimDocuments.documentType
            ORDER BY count DESC""")

cursor.execute(query)
query = cursor.fetchall()
query
# Out:
# [('CTPS', 3377), ('CNH', 3330), ('RG', 3292), ('-', 3)]

# %%
# questão extra usando SQL.
query = ("""SELECT t1.*
            FROM factTransactions t1
            LEFT JOIN factTransactions t2 ON t1._id = t2._id AND t1.updatedAt < t2.updatedAt
            WHERE t2._id IS NULL""")

cursor.execute(query)
query = cursor.fetchall()
query
# Out:
# [(14944,
#   15610,
#   1,
#   '641336ef000b2ce307b655c6',
#   '64132ef662f97d5858f87aba',
#   '64132e0ffe16938ae5708fb3',
#   datetime.datetime(2021, 4, 18, 2, 56, 39),
#   datetime.datetime(2023, 2, 13, 1, 11, 3),
#   'banana',
#   0),
#  (14874,
#   15608,
#   9,
#   '641336ef0012d7b5dfccf81d',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f72148c806c32b064',
#   datetime.datetime(2021, 2, 7, 10, 58, 22),
#   datetime.datetime(2023, 2, 11, 11, 42, 20),
#   'strawberry',
#   0),
#  (15206,
#   15568,
#   33,
#   '641336ef00224417c62cfdf5',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0fc7534e992bafa834',
#   datetime.datetime(2022, 1, 5, 3, 49, 30),
#   datetime.datetime(2023, 1, 2, 1, 28, 25),
#   'apple',
#   1),
#  (15217,
#   15570,
#   63,
#   '641336ef00337c3444c99a78',
#   '64132ef68637da8c371cdc09',
#   '64132e0f555673bb72251b1d',
#   datetime.datetime(2022, 1, 16, 11, 42, 35),
#   datetime.datetime(2023, 1, 4, 12, 17, 18),
#   'apple',
#   0),
#  (15437,
#   15581,
#   22,
#   '641336ef00338af0a965428b',
#   '64132ef662f97d5858f87aba',
#   '64132e0f29d8b74c6b1cb514',
#   datetime.datetime(2022, 8, 24, 4, 41, 35),
#   datetime.datetime(2023, 1, 15, 3, 42, 11),
#   'apple',
#   0),
#  (14932,
#   15570,
#   2,
#   '641336ef003667db76fdfe58',
#   '64132ef6eea665cc154f614a',
#   '64132e0fe14d128d168160e4',
#   datetime.datetime(2021, 4, 6, 3, 25, 17),
#   datetime.datetime(2023, 1, 4, 6, 7, 5),
#   'strawberry',
#   1),
#  (15561,
#   15599,
#   3,
#   '641336ef003ef816a7a50c7f',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0fdecad60766d8ab2c',
#   datetime.datetime(2022, 12, 26, 4, 47, 59),
#   datetime.datetime(2023, 2, 2, 11, 53, 43),
#   'apple',
#   1),
#  (15078,
#   15608,
#   39,
#   '641336ef004e1abcace8f1d2',
#   '64132ef662f97d5858f87aba',
#   '64132e0f4884b463e3fa4bb5',
#   datetime.datetime(2021, 8, 30, 1, 30, 35),
#   datetime.datetime(2023, 2, 11, 6, 2, 50),
#   'apple',
#   0),
#  (15023,
#   15581,
#   2,
#   '641336ef0053cb5e9cc17404',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0ff769e21f3707d966',
#   datetime.datetime(2021, 7, 6, 2, 54, 9),
#   datetime.datetime(2023, 1, 15, 10, 42, 7),
#   'banana',
#   1),
#  (15373,
#   15612,
#   1,
#   '641336ef0058d70e66b1d838',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0fbb8283fc0ab24791',
#   datetime.datetime(2022, 6, 21, 3, 58, 48),
#   datetime.datetime(2023, 2, 15, 3, 9, 34),
#   'strawberry',
#   1),
#  (15223,
#   15625,
#   34,
#   '641336ef006076173a2d3f14',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f7aee8254eafaa63a',
#   datetime.datetime(2022, 1, 22, 12, 3, 1),
#   datetime.datetime(2023, 2, 28, 9, 3, 2),
#   'banana',
#   1),
#  (15373,
#   15623,
#   15,
#   '641336ef00635dc43aec3ce2',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f8ad64890298e4d1e',
#   datetime.datetime(2022, 6, 21, 1, 55, 8),
#   datetime.datetime(2023, 2, 26, 5, 23, 16),
#   'strawberry',
#   1),
#  (15090,
#   15625,
#   63,
#   '641336ef006467cc76a25018',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f85b016750b1e4f8e',
#   datetime.datetime(2021, 9, 11, 8, 32, 53),
#   datetime.datetime(2023, 2, 28, 9, 28, 1),
#   'apple',
#   0),
#  (15267,
#   15588,
#   39,
#   '641336ef0065a153ffb1cee5',
#   '64132ef6eea665cc154f614a',
#   '64132e0f7847d1ad65a92102',
#   datetime.datetime(2022, 3, 7, 6, 33, 59),
#   datetime.datetime(2023, 1, 22, 5, 59, 53),
#   'strawberry',
#   0),
#  (15376,
#   15599,
#   0,
#   '641336ef007d168e56a60e1a',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f72bb82a25ea19ecb',
#   datetime.datetime(2022, 6, 24, 5, 6, 32),
#   datetime.datetime(2023, 2, 2, 6, 7, 3),
#   'strawberry',
#   0),
#  (15124,
#   15606,
#   15,
#   '641336ef008c132dade2548f',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0ff31bfea3ecc4d0b6',
#   datetime.datetime(2021, 10, 15, 4, 35, 43),
#   datetime.datetime(2023, 2, 9, 7, 8, 55),
#   'apple',
#   0),
#  (14963,
#   15618,
#   29,
#   '641336ef008d5f1603628a64',
#   '64132ef662f97d5858f87aba',
#   '64132e0f022a91f2806aaefe',
#   datetime.datetime(2021, 5, 7, 5, 36, 55),
#   datetime.datetime(2023, 2, 21, 5, 4, 25),
#   'strawberry',
#   0),
#  (15091,
#   15635,
#   1,
#   '641336ef0092fddcb74b82f3',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f74cda6acaa908563',
#   datetime.datetime(2021, 9, 12, 2, 29, 59),
#   datetime.datetime(2023, 3, 10, 2, 18, 58),
#   'banana',
#   0),
#  (15428,
#   15578,
#   63,
#   '641336ef00973bd9a06c485b',
#   '64132ef6eea665cc154f614a',
#   '64132e0f1eeec2acd297c0e9',
#   datetime.datetime(2022, 8, 15, 5, 46, 24),
#   datetime.datetime(2023, 1, 12, 4, 14, 14),
#   'strawberry',
#   0),
#  (14880,
#   15593,
#   9,
#   '641336ef009d1236d6029d9a',
#   '64132ef662f97d5858f87aba',
#   '64132e0f56dd370a14cd262a',
#   datetime.datetime(2021, 2, 13, 12, 2, 47),
#   datetime.datetime(2023, 1, 27, 10, 21, 29),
#   'banana',
#   0),
#  (14923,
#   15594,
#   2,
#   '641336ef00a31a36b7918cd5',
#   '64132ef662f97d5858f87aba',
#   '64132e0f19d8c115ba93536c',
#   datetime.datetime(2021, 3, 28, 12, 10, 28),
#   datetime.datetime(2023, 1, 28, 6, 42, 39),
#   'apple',
#   1),
#  (15087,
#   15597,
#   5,
#   '641336ef00a6c5b77b531c80',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f85b016750b1e4f8e',
#   datetime.datetime(2021, 9, 8, 8, 4, 22),
#   datetime.datetime(2023, 1, 31, 10, 21, 24),
#   'strawberry',
#   1),
#  (15205,
#   15570,
#   4,
#   '641336ef00a6eed1f9593e10',
#   '64132ef6eea665cc154f614a',
#   '64132e0f49625262850d71ab',
#   datetime.datetime(2022, 1, 4, 6, 23, 10),
#   datetime.datetime(2023, 1, 4, 5, 5, 31),
#   'strawberry',
#   0),
#  (15136,
#   15608,
#   29,
#   '641336ef00a84bbca534e862',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f63c1a33ae32d7a99',
#   datetime.datetime(2021, 10, 27, 4, 46, 59),
#   datetime.datetime(2023, 2, 11, 3, 4, 21),
#   'apple',
#   1),
#  (15445,
#   15627,
#   29,
#   '641336ef00abcdd4977e2589',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f8df1cb7b954fecf9',
#   datetime.datetime(2022, 9, 1, 12, 36, 4),
#   datetime.datetime(2023, 3, 2, 1, 57, 55),
#   'strawberry',
#   1),
#  (15310,
#   15582,
#   9,
#   '641336ef00b77edd6ad0ed9f',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f72bb82a25ea19ecb',
#   datetime.datetime(2022, 4, 19, 10, 27, 4),
#   datetime.datetime(2023, 1, 16, 12, 42, 43),
#   'strawberry',
#   0),
#  (15104,
#   15605,
#   1,
#   '641336ef00c0fca62b5c3437',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fccaa6cd8f625d942',
#   datetime.datetime(2021, 9, 25, 1, 10),
#   datetime.datetime(2023, 2, 8, 5, 46, 43),
#   'apple',
#   1),
#  (15544,
#   15606,
#   9,
#   '641336ef00c6f4f4b7ab35ff',
#   '64132ef68637da8c371cdc09',
#   '64132e0f7da24bcd8d8ca3fb',
#   datetime.datetime(2022, 12, 9, 10, 1, 50),
#   datetime.datetime(2023, 2, 9, 1, 10, 48),
#   'strawberry',
#   1),
#  (15126,
#   15631,
#   34,
#   '641336ef00cfc94a6c2ef6f8',
#   '64132ef6eea665cc154f614a',
#   '64132e0f8e3082f0517fdfdb',
#   datetime.datetime(2021, 10, 17, 8, 58, 33),
#   datetime.datetime(2023, 3, 6, 10, 43, 58),
#   'strawberry',
#   1),
#  (15067,
#   15604,
#   63,
#   '641336ef00d004164c4527f4',
#   '64132ef6c9c22c95893e388b',
#   '64132e0fb611e00924b0b8e0',
#   datetime.datetime(2021, 8, 19, 4, 26, 18),
#   datetime.datetime(2023, 2, 7, 12, 57, 24),
#   'strawberry',
#   1),
#  (15062,
#   15592,
#   10,
#   '641336ef00d2a2a62c10a4ba',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f05e9b1d120893ffe',
#   datetime.datetime(2021, 8, 14, 9, 56, 9),
#   datetime.datetime(2023, 1, 26, 11, 25, 16),
#   'apple',
#   1),
#  (14882,
#   15630,
#   22,
#   '641336ef00f07803afc47f4c',
#   '64132ef6c9c22c95893e388b',
#   '64132e0fb3c06ddc6c896f5b',
#   datetime.datetime(2021, 2, 15, 5, 22, 48),
#   datetime.datetime(2023, 3, 5, 9, 3, 34),
#   'apple',
#   0),
#  (15393,
#   15624,
#   15,
#   '641336ef00f113baba3e8e20',
#   '64132ef68637da8c371cdc09',
#   '64132e0f7847d1ad65a92102',
#   datetime.datetime(2022, 7, 11, 9, 59, 41),
#   datetime.datetime(2023, 2, 27, 9, 6, 25),
#   'banana',
#   0),
#  (15233,
#   15572,
#   3,
#   '641336ef00f231d716f9db2c',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f68da4c705b3b80e0',
#   datetime.datetime(2022, 2, 1, 8, 34, 59),
#   datetime.datetime(2023, 1, 6, 3, 26, 16),
#   'banana',
#   1),
#  (15502,
#   15569,
#   21,
#   '641336ef00f330656034fc7e',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f25f70db60e2eeb8e',
#   datetime.datetime(2022, 10, 28, 1, 28, 53),
#   datetime.datetime(2023, 1, 3, 1, 46, 6),
#   'strawberry',
#   0),
#  (15425,
#   15588,
#   10,
#   '641336ef00f3bc6655d05c5a',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f0abcd78da3792cfe',
#   datetime.datetime(2022, 8, 12, 4, 29, 34),
#   datetime.datetime(2023, 1, 22, 11, 46, 50),
#   'apple',
#   0),
#  (15339,
#   15610,
#   0,
#   '641336ef00f766f3d428c45f',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f05f9e9ca1e250a65',
#   datetime.datetime(2022, 5, 18, 4, 15, 13),
#   datetime.datetime(2023, 2, 13, 8, 22, 29),
#   'strawberry',
#   0),
#  (15465,
#   15631,
#   39,
#   '641336ef00fa1380a324a5e6',
#   '64132ef6eea665cc154f614a',
#   '64132e0f0bda9c4ebba64c82',
#   datetime.datetime(2022, 9, 21, 5, 14, 38),
#   datetime.datetime(2023, 3, 6, 6, 32, 51),
#   'strawberry',
#   0),
#  (15379,
#   15627,
#   34,
#   '641336ef00fa83bbf46ae474',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f05e9b1d120893ffe',
#   datetime.datetime(2022, 6, 27, 6, 30, 35),
#   datetime.datetime(2023, 3, 2, 8, 37, 4),
#   'strawberry',
#   1),
#  (14972,
#   15627,
#   13,
#   '641336ef01035035b5958c1e',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f72148c806c32b064',
#   datetime.datetime(2021, 5, 16, 10, 52, 43),
#   datetime.datetime(2023, 3, 2, 6, 29, 44),
#   'strawberry',
#   1),
#  (15122,
#   15637,
#   22,
#   '641336ef0104c2e7188e83ae',
#   '64132ef6eea665cc154f614a',
#   '64132e0fd0fd03a2161eade3',
#   datetime.datetime(2021, 10, 13, 10, 15),
#   datetime.datetime(2023, 3, 12, 6, 52, 7),
#   'strawberry',
#   1),
#  (15268,
#   15579,
#   9,
#   '641336ef010650ae5e374a9f',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f7aee8254eafaa63a',
#   datetime.datetime(2022, 3, 8, 1, 38, 27),
#   datetime.datetime(2023, 1, 13, 12, 42, 14),
#   'banana',
#   0),
#  (15384,
#   15578,
#   2,
#   '641336ef0112e1604b8bc8ce',
#   '64132ef68637da8c371cdc09',
#   '64132e0f022a91f2806aaefe',
#   datetime.datetime(2022, 7, 2, 6, 24, 57),
#   datetime.datetime(2023, 1, 12, 3, 58, 34),
#   'banana',
#   1),
#  (15264,
#   15573,
#   4,
#   '641336ef0118ce4f283c0e06',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f85b016750b1e4f8e',
#   datetime.datetime(2022, 3, 4, 4, 25, 32),
#   datetime.datetime(2023, 1, 7, 8, 46, 24),
#   'apple',
#   0),
#  (15440,
#   15616,
#   5,
#   '641336ef0119ff266ed849f3',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f19d8c115ba93536c',
#   datetime.datetime(2022, 8, 27, 12, 5, 53),
#   datetime.datetime(2023, 2, 19, 11, 5, 51),
#   'strawberry',
#   1),
#  (14966,
#   15581,
#   10,
#   '641336ef01221944cc564c85',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f9647ed73a005c271',
#   datetime.datetime(2021, 5, 10, 8, 10, 1),
#   datetime.datetime(2023, 1, 15, 1, 49, 12),
#   'strawberry',
#   0),
#  (15492,
#   15568,
#   4,
#   '641336ef01297ebe47c53e27',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f4884b463e3fa4bb5',
#   datetime.datetime(2022, 10, 18, 3, 27, 40),
#   datetime.datetime(2023, 1, 2, 8, 36, 8),
#   'banana',
#   1),
#  (15564,
#   15633,
#   10,
#   '641336ef01301ea768aa8d60',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f4884b463e3fa4bb5',
#   datetime.datetime(2022, 12, 29, 7, 26, 57),
#   datetime.datetime(2023, 3, 8, 2, 19, 5),
#   'apple',
#   1),
#  (15158,
#   15589,
#   2,
#   '641336ef013bba8aa6427cac',
#   '64132ef6eea665cc154f614a',
#   '64132e0fe7a0ca7f994cca17',
#   datetime.datetime(2021, 11, 18, 1, 49, 57),
#   datetime.datetime(2023, 1, 23, 7, 2, 37),
#   'banana',
#   0),
#  (14867,
#   15632,
#   0,
#   '641336ef013db0bf34059ad2',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f48ad8ae93e504d33',
#   datetime.datetime(2021, 1, 31, 9, 28, 7),
#   datetime.datetime(2023, 3, 7, 6, 33, 11),
#   'banana',
#   1),
#  (15513,
#   15618,
#   29,
#   '641336ef014333dc288ab81b',
#   '64132ef662f97d5858f87aba',
#   '64132e0f9647ed73a005c271',
#   datetime.datetime(2022, 11, 8, 6, 44, 9),
#   datetime.datetime(2023, 2, 21, 6, 24, 10),
#   'strawberry',
#   1),
#  (15152,
#   15636,
#   34,
#   '641336ef014abf79f61df83e',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f5db21511f29bd2c3',
#   datetime.datetime(2021, 11, 12, 1, 42, 55),
#   datetime.datetime(2023, 3, 11, 1, 47, 15),
#   'strawberry',
#   1),
#  (15263,
#   15604,
#   1,
#   '641336ef014d5db7be55a1a1',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0fa1b98612a1366a0a',
#   datetime.datetime(2022, 3, 3, 5, 15, 59),
#   datetime.datetime(2023, 2, 7, 9, 23, 23),
#   'apple',
#   1),
#  (15446,
#   15575,
#   6,
#   '641336ef014eeea7d2440a9e',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f8e3082f0517fdfdb',
#   datetime.datetime(2022, 9, 2, 11, 27, 20),
#   datetime.datetime(2023, 1, 9, 7, 20, 7),
#   'strawberry',
#   0),
#  (14858,
#   15577,
#   0,
#   '641336ef0156d5c08ec6b465',
#   '64132ef6eea665cc154f614a',
#   '64132e0f1d87f017f64a3c20',
#   datetime.datetime(2021, 1, 22, 3, 41, 29),
#   datetime.datetime(2023, 1, 11, 3, 2, 21),
#   'banana',
#   1),
#  (15282,
#   15572,
#   13,
#   '641336ef015d69ea473f7e21',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0fe14d128d168160e4',
#   datetime.datetime(2022, 3, 22, 8, 37, 3),
#   datetime.datetime(2023, 1, 6, 3, 10, 13),
#   'strawberry',
#   1),
#  (15124,
#   15577,
#   4,
#   '641336ef0162d9205d9366cc',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f48ad8ae93e504d33',
#   datetime.datetime(2021, 10, 15, 2, 40, 48),
#   datetime.datetime(2023, 1, 11, 6, 2),
#   'apple',
#   1),
#  (15108,
#   15599,
#   21,
#   '641336ef0166eb9a829f99cd',
#   '64132ef6eea665cc154f614a',
#   '64132e0f00e22f4ac7b67520',
#   datetime.datetime(2021, 9, 29, 9, 55, 21),
#   datetime.datetime(2023, 2, 2, 7, 21, 23),
#   'banana',
#   1),
#  (15019,
#   15612,
#   10,
#   '641336ef0175e07cdb7fedd3',
#   '64132ef68637da8c371cdc09',
#   '64132e0fc77ec324b4a3b1d6',
#   datetime.datetime(2021, 7, 2, 11, 18, 8),
#   datetime.datetime(2023, 2, 15, 5, 41, 40),
#   'apple',
#   0),
#  (15438,
#   15581,
#   5,
#   '641336ef0179b287077a4ddf',
#   '64132ef6eea665cc154f614a',
#   '64132e0f9417d076f85b8f61',
#   datetime.datetime(2022, 8, 25, 5, 6, 2),
#   datetime.datetime(2023, 1, 15, 12, 48, 5),
#   'banana',
#   1),
#  (14942,
#   15633,
#   39,
#   '641336ef017ce8b4da831fed',
#   '64132ef6eea665cc154f614a',
#   '64132e0f68da4c705b3b80e0',
#   datetime.datetime(2021, 4, 16, 4, 10, 22),
#   datetime.datetime(2023, 3, 8, 6, 47, 50),
#   'banana',
#   1),
#  (15141,
#   15583,
#   63,
#   '641336ef018855ced34c7157',
#   '64132ef6c9c22c95893e388b',
#   '64132e0ff31bfea3ecc4d0b6',
#   datetime.datetime(2021, 11, 1, 4, 39, 55),
#   datetime.datetime(2023, 1, 17, 8, 38, 58),
#   'apple',
#   1),
#  (15497,
#   15583,
#   2,
#   '641336ef0188d624b12f1946',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f0bda9c4ebba64c82',
#   datetime.datetime(2022, 10, 23, 10, 16, 12),
#   datetime.datetime(2023, 1, 17, 6, 52, 6),
#   'banana',
#   0),
#  (14869,
#   15631,
#   39,
#   '641336ef018903cceec1739c',
#   '64132ef662f97d5858f87aba',
#   '64132e0f555673bb72251b1d',
#   datetime.datetime(2021, 2, 2, 1, 28, 39),
#   datetime.datetime(2023, 3, 6, 11, 11, 22),
#   'apple',
#   0),
#  (15192,
#   15578,
#   9,
#   '641336ef018ce067231d4e13',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f7847d1ad65a92102',
#   datetime.datetime(2021, 12, 22, 1, 8, 26),
#   datetime.datetime(2023, 1, 12, 2, 30, 18),
#   'strawberry',
#   1),
#  (15449,
#   15624,
#   1,
#   '641336ef019337d2ba08d80d',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f58ce216e866593d6',
#   datetime.datetime(2022, 9, 5, 7, 37, 49),
#   datetime.datetime(2023, 2, 27, 1, 54, 26),
#   'strawberry',
#   0),
#  (15159,
#   15585,
#   34,
#   '641336ef01950c80e637d188',
#   '64132ef662f97d5858f87aba',
#   '64132e0f555673bb72251b1d',
#   datetime.datetime(2021, 11, 19, 7, 37, 41),
#   datetime.datetime(2023, 1, 19, 12, 14, 3),
#   'strawberry',
#   0),
#  (15069,
#   15583,
#   13,
#   '641336ef01a5a5f5ab1197ab',
#   '64132ef662f97d5858f87aba',
#   '64132e0fddc4fe73fd258a24',
#   datetime.datetime(2021, 8, 21, 8, 42, 24),
#   datetime.datetime(2023, 1, 17, 3, 2, 6),
#   'apple',
#   0),
#  (15391,
#   15627,
#   39,
#   '641336ef01a62aeb4f86fe90',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f95dc386b40202460',
#   datetime.datetime(2022, 7, 9, 8, 2, 18),
#   datetime.datetime(2023, 3, 2, 12, 8, 15),
#   'strawberry',
#   0),
#  (15281,
#   15589,
#   1,
#   '641336ef01b1d2588e5ca535',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0ff99f08aa40f089ae',
#   datetime.datetime(2022, 3, 21, 8, 11, 20),
#   datetime.datetime(2023, 1, 23, 1, 11, 10),
#   'apple',
#   1),
#  (15507,
#   15590,
#   10,
#   '641336ef01b27cb7393ef4f4',
#   '64132ef68637da8c371cdc09',
#   '64132e0fd3bdca816cd9ac2f',
#   datetime.datetime(2022, 11, 2, 5, 15, 6),
#   datetime.datetime(2023, 1, 24, 11, 10, 10),
#   'banana',
#   0),
#  (15439,
#   15579,
#   33,
#   '641336ef01b76bfb5e9c1ee0',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0fc615332b14dfbd62',
#   datetime.datetime(2022, 8, 26, 3, 10, 57),
#   datetime.datetime(2023, 1, 13, 6, 44, 3),
#   'banana',
#   0),
#  (15109,
#   15591,
#   3,
#   '641336ef01bac72d4706d884',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f0abcd78da3792cfe',
#   datetime.datetime(2021, 9, 30, 7, 47, 17),
#   datetime.datetime(2023, 1, 25, 10, 52, 53),
#   'apple',
#   1),
#  (15128,
#   15580,
#   33,
#   '641336ef01c1acb9ffad0fd3',
#   '64132ef662f97d5858f87aba',
#   '64132e0f29d8b74c6b1cb514',
#   datetime.datetime(2021, 10, 19, 10, 59, 51),
#   datetime.datetime(2023, 1, 14, 1, 51, 45),
#   'apple',
#   1),
#  (14851,
#   15584,
#   39,
#   '641336ef01c1d603f7162e2c',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f60176a0a0afefe23',
#   datetime.datetime(2021, 1, 15, 3, 41, 14),
#   datetime.datetime(2023, 1, 18, 1, 36, 5),
#   'apple',
#   1),
#  (15381,
#   15569,
#   10,
#   '641336ef01c3a563f902de4d',
#   '64132ef6eea665cc154f614a',
#   '64132e0feb28dcda49522904',
#   datetime.datetime(2022, 6, 29, 12, 55, 34),
#   datetime.datetime(2023, 1, 3, 7, 40, 41),
#   'strawberry',
#   0),
#  (14857,
#   15581,
#   3,
#   '641336ef01c9442024d93bdd',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0fdecad60766d8ab2c',
#   datetime.datetime(2021, 1, 21, 4, 30),
#   datetime.datetime(2023, 1, 15, 10, 48, 37),
#   'apple',
#   1),
#  (15327,
#   15593,
#   2,
#   '641336ef01cda954e7f1752f',
#   '64132ef6eea665cc154f614a',
#   '64132e0f9417d076f85b8f61',
#   datetime.datetime(2022, 5, 6, 3, 37, 22),
#   datetime.datetime(2023, 1, 27, 6, 5, 49),
#   'banana',
#   1),
#  (14837,
#   15583,
#   4,
#   '641336ef01d53a362f670461',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0ff7c0a95b1a0707b0',
#   datetime.datetime(2021, 1, 1, 11, 50, 53),
#   datetime.datetime(2023, 1, 17, 4, 19, 41),
#   'strawberry',
#   0),
#  (15042,
#   15610,
#   5,
#   '641336ef01d5ad6fc2e094bc',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f9647ed73a005c271',
#   datetime.datetime(2021, 7, 25, 2, 40, 41),
#   datetime.datetime(2023, 2, 13, 7, 20, 16),
#   'banana',
#   1),
#  (15361,
#   15586,
#   4,
#   '641336ef01e0929e04182f2b',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f483bdb42b75e860c',
#   datetime.datetime(2022, 6, 9, 8, 25, 16),
#   datetime.datetime(2023, 1, 20, 3, 8, 38),
#   'strawberry',
#   1),
#  (15512,
#   15586,
#   39,
#   '641336ef01f2b303823e3bd2',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0ff7c0a95b1a0707b0',
#   datetime.datetime(2022, 11, 7, 11, 34, 25),
#   datetime.datetime(2023, 1, 20, 1, 56, 10),
#   'strawberry',
#   1),
#  (15383,
#   15572,
#   1,
#   '641336ef01fdf9713a717214',
#   '64132ef662f97d5858f87aba',
#   '64132e0f74cda6acaa908563',
#   datetime.datetime(2022, 7, 1, 11, 53, 13),
#   datetime.datetime(2023, 1, 6, 11, 2, 16),
#   'apple',
#   1),
#  (14986,
#   15617,
#   9,
#   '641336ef02020b4d1cb1c671',
#   '64132ef6c9c22c95893e388b',
#   '64132e0fe7a0ca7f994cca17',
#   datetime.datetime(2021, 5, 30, 9, 28, 55),
#   datetime.datetime(2023, 2, 20, 10, 55, 36),
#   'banana',
#   1),
#  (14878,
#   15593,
#   10,
#   '641336ef0202efb06575be81',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f00e22f4ac7b67520',
#   datetime.datetime(2021, 2, 11, 1, 29, 25),
#   datetime.datetime(2023, 1, 27, 12, 19, 38),
#   'strawberry',
#   1),
#  (15309,
#   15625,
#   13,
#   '641336ef020d070932030bbf',
#   '64132ef662f97d5858f87aba',
#   '64132e0f407b51b8b5dc2dba',
#   datetime.datetime(2022, 4, 18, 3, 50, 39),
#   datetime.datetime(2023, 2, 28, 5, 54, 20),
#   'apple',
#   1),
#  (14924,
#   15636,
#   6,
#   '641336ef020eebd3f3d72261',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0fac889c7cbd7ebda3',
#   datetime.datetime(2021, 3, 29, 11, 29, 56),
#   datetime.datetime(2023, 3, 11, 7, 25, 5),
#   'banana',
#   1),
#  (15547,
#   15599,
#   39,
#   '641336ef021c8cbe55f1c3b7',
#   '64132ef6eea665cc154f614a',
#   '64132e0ff769e21f3707d966',
#   datetime.datetime(2022, 12, 12, 9, 6, 16),
#   datetime.datetime(2023, 2, 2, 7, 16, 42),
#   'strawberry',
#   1),
#  (15249,
#   15607,
#   33,
#   '641336ef021dabf0816e2277',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f9647ed73a005c271',
#   datetime.datetime(2022, 2, 17, 6, 58),
#   datetime.datetime(2023, 2, 10, 7, 28, 7),
#   'apple',
#   0),
#  (15403,
#   15611,
#   39,
#   '641336ef022030e25792c101',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f8ad64890298e4d1e',
#   datetime.datetime(2022, 7, 21, 3, 39, 10),
#   datetime.datetime(2023, 2, 14, 3, 22, 35),
#   'banana',
#   1),
#  (14965,
#   15607,
#   34,
#   '641336ef0222c38d1f15b969',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f555673bb72251b1d',
#   datetime.datetime(2021, 5, 9, 9, 24, 19),
#   datetime.datetime(2023, 2, 10, 11, 6, 5),
#   'apple',
#   0),
#  (14863,
#   15593,
#   10,
#   '641336ef0222c5026562c3b0',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f8e3082f0517fdfdb',
#   datetime.datetime(2021, 1, 27, 10, 48),
#   datetime.datetime(2023, 1, 27, 3, 20, 16),
#   'apple',
#   1),
#  (15545,
#   15637,
#   5,
#   '641336ef0227c2d7cbb5eab3',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f56a8e4996c9497b4',
#   datetime.datetime(2022, 12, 10, 10, 55, 31),
#   datetime.datetime(2023, 3, 12, 4, 29, 16),
#   'banana',
#   0),
#  (15489,
#   15631,
#   10,
#   '641336ef022b631971d33b89',
#   '64132ef662f97d5858f87aba',
#   '64132e0fe7a0ca7f994cca17',
#   datetime.datetime(2022, 10, 15, 10, 9, 24),
#   datetime.datetime(2023, 3, 6, 6, 4, 52),
#   'strawberry',
#   0),
#  (14937,
#   15586,
#   2,
#   '641336ef0230e52a3077d913',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0fe14d128d168160e4',
#   datetime.datetime(2021, 4, 11, 10, 1, 57),
#   datetime.datetime(2023, 1, 20, 11, 54, 8),
#   'banana',
#   1),
#  (14928,
#   15606,
#   63,
#   '641336ef0237379fe2ff6be7',
#   '64132ef6eea665cc154f614a',
#   '64132e0fccaa6cd8f625d942',
#   datetime.datetime(2021, 4, 2, 9, 33, 43),
#   datetime.datetime(2023, 2, 9, 3, 59, 14),
#   'apple',
#   0),
#  (15437,
#   15619,
#   0,
#   '641336ef0237a48caf3836ff',
#   '64132ef6c9c22c95893e388b',
#   '64132e0ff99f08aa40f089ae',
#   datetime.datetime(2022, 8, 24, 1, 37, 50),
#   datetime.datetime(2023, 2, 22, 9, 47, 56),
#   'apple',
#   1),
#  (15538,
#   15588,
#   10,
#   '641336ef023971c8469d9e02',
#   '64132ef662f97d5858f87aba',
#   '64132e0f05e9b1d120893ffe',
#   datetime.datetime(2022, 12, 3, 1, 25, 43),
#   datetime.datetime(2023, 1, 22, 5, 4, 39),
#   'strawberry',
#   0),
#  (15398,
#   15613,
#   2,
#   '641336ef023fee7e4c87e3c9',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f63c1a33ae32d7a99',
#   datetime.datetime(2022, 7, 16, 10, 21, 35),
#   datetime.datetime(2023, 2, 16, 9, 20, 1),
#   'strawberry',
#   1),
#  (15379,
#   15637,
#   15,
#   '641336ef0251469b6c4a8694',
#   '64132ef6eea665cc154f614a',
#   '64132e0fa397563115444821',
#   datetime.datetime(2022, 6, 27, 5, 19, 14),
#   datetime.datetime(2023, 3, 12, 6, 40, 11),
#   'strawberry',
#   1),
#  (15304,
#   15569,
#   9,
#   '641336ef0260c3bb52552b1b',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0fc8ad114d29212998',
#   datetime.datetime(2022, 4, 13, 6, 3, 46),
#   datetime.datetime(2023, 1, 3, 2, 7, 24),
#   'strawberry',
#   0),
#  (14851,
#   15601,
#   4,
#   '641336ef02685b484dee3dbf',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f67e98be3094ec5c9',
#   datetime.datetime(2021, 1, 15, 10, 35, 39),
#   datetime.datetime(2023, 2, 4, 11, 13, 15),
#   'strawberry',
#   0),
#  (14963,
#   15639,
#   13,
#   '641336ef02706e8fcd9591c3',
#   '64132ef68637da8c371cdc09',
#   '64132e0f85b016750b1e4f8e',
#   datetime.datetime(2021, 5, 7, 12, 15, 57),
#   datetime.datetime(2023, 3, 14, 5, 22, 29),
#   'strawberry',
#   0),
#  (15005,
#   15597,
#   39,
#   '641336ef0271c511eeb16939',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f0abcd78da3792cfe',
#   datetime.datetime(2021, 6, 18, 3, 48, 7),
#   datetime.datetime(2023, 1, 31, 9, 36, 18),
#   'banana',
#   1),
#  (15506,
#   15571,
#   63,
#   '641336ef02788e17e29e1944',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f67e98be3094ec5c9',
#   datetime.datetime(2022, 11, 1, 6, 21, 38),
#   datetime.datetime(2023, 1, 5, 8, 11, 11),
#   'strawberry',
#   0),
#  (14970,
#   15630,
#   2,
#   '641336ef0281319170306871',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f7aee8254eafaa63a',
#   datetime.datetime(2021, 5, 14, 5, 15, 34),
#   datetime.datetime(2023, 3, 5, 9, 4, 45),
#   'apple',
#   0),
#  (15022,
#   15616,
#   21,
#   '641336ef0286c45207316c9f',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0fec1b702b2378c379',
#   datetime.datetime(2021, 7, 5, 12, 8, 30),
#   datetime.datetime(2023, 2, 19, 4, 46, 18),
#   'apple',
#   0),
#  (14878,
#   15590,
#   39,
#   '641336ef0296e7427c87823a',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f67e98be3094ec5c9',
#   datetime.datetime(2021, 2, 11, 10, 6, 27),
#   datetime.datetime(2023, 1, 24, 11, 39, 12),
#   'strawberry',
#   0),
#  (15319,
#   15638,
#   0,
#   '641336ef0298caf0abe00907',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f95dc386b40202460',
#   datetime.datetime(2022, 4, 28, 8, 29, 30),
#   datetime.datetime(2023, 3, 13, 9, 6, 55),
#   'banana',
#   1),
#  (15017,
#   15605,
#   63,
#   '641336ef029b5b96372334f0',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f85b016750b1e4f8e',
#   datetime.datetime(2021, 6, 30, 3, 31, 2),
#   datetime.datetime(2023, 2, 8, 7, 46, 3),
#   'banana',
#   1),
#  (14919,
#   15639,
#   10,
#   '641336ef02a22c7d6e1f0261',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f1c3cdc367a6667aa',
#   datetime.datetime(2021, 3, 24, 12, 4, 18),
#   datetime.datetime(2023, 3, 14, 8, 10, 45),
#   'banana',
#   1),
#  (15181,
#   15638,
#   3,
#   '641336ef02a3484a400e81dc',
#   '64132ef662f97d5858f87aba',
#   '64132e0f63c1a33ae32d7a99',
#   datetime.datetime(2021, 12, 11, 3, 0, 2),
#   datetime.datetime(2023, 3, 13, 7, 55, 54),
#   'banana',
#   1),
#  (15329,
#   15632,
#   33,
#   '641336ef02a366abe44165e5',
#   '64132ef68637da8c371cdc09',
#   '64132e0f5db21511f29bd2c3',
#   datetime.datetime(2022, 5, 8, 2, 18, 51),
#   datetime.datetime(2023, 3, 7, 10, 17, 54),
#   'apple',
#   1),
#  (15348,
#   15583,
#   63,
#   '641336ef02acfba95807d862',
#   '64132ef6eea665cc154f614a',
#   '64132e0fb3c06ddc6c896f5b',
#   datetime.datetime(2022, 5, 27, 2, 26, 17),
#   datetime.datetime(2023, 1, 17, 1, 24, 17),
#   'apple',
#   1),
#  (15266,
#   15619,
#   3,
#   '641336ef02b7fcac07cbf35e',
#   '64132ef6c9c22c95893e388b',
#   '64132e0fb4fade825fdbeed4',
#   datetime.datetime(2022, 3, 6, 3, 54, 51),
#   datetime.datetime(2023, 2, 22, 6, 29, 21),
#   'apple',
#   1),
#  (15413,
#   15636,
#   21,
#   '641336ef02c1a8946c63cac3',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f85b016750b1e4f8e',
#   datetime.datetime(2022, 7, 31, 8, 52, 6),
#   datetime.datetime(2023, 3, 11, 3, 35, 39),
#   'strawberry',
#   0),
#  (15147,
#   15614,
#   4,
#   '641336ef02c33102fc3d0c7b',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f8df1cb7b954fecf9',
#   datetime.datetime(2021, 11, 7, 12, 2, 51),
#   datetime.datetime(2023, 2, 17, 6, 33, 20),
#   'banana',
#   1),
#  (14981,
#   15639,
#   0,
#   '641336ef02c3988968755ee9',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fb3c06ddc6c896f5b',
#   datetime.datetime(2021, 5, 25, 11, 14, 29),
#   datetime.datetime(2023, 3, 14, 1, 46, 46),
#   'banana',
#   0),
#  (14899,
#   15636,
#   39,
#   '641336ef02c3c36549e6ec65',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f6f7f7af7c4dfe156',
#   datetime.datetime(2021, 3, 4, 12, 57, 41),
#   datetime.datetime(2023, 3, 11, 3, 9, 47),
#   'banana',
#   1),
#  (14939,
#   15613,
#   63,
#   '641336ef02c9bee344cbacaa',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0fec1b702b2378c379',
#   datetime.datetime(2021, 4, 13, 3, 57, 50),
#   datetime.datetime(2023, 2, 16, 9, 41, 22),
#   'banana',
#   0),
#  (15147,
#   15619,
#   6,
#   '641336ef02d6aa54c135fcd3',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0fa078fea397f180eb',
#   datetime.datetime(2021, 11, 7, 11, 33, 57),
#   datetime.datetime(2023, 2, 22, 10, 50, 3),
#   'apple',
#   0),
#  (14849,
#   15587,
#   22,
#   '641336ef02d76581c3d076ff',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f861fcfbc0c1ca217',
#   datetime.datetime(2021, 1, 13, 5, 31, 28),
#   datetime.datetime(2023, 1, 21, 9, 41, 58),
#   'strawberry',
#   1),
#  (14887,
#   15588,
#   22,
#   '641336ef02dea57c9fa9c6ac',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f1d87f017f64a3c20',
#   datetime.datetime(2021, 2, 20, 9, 58, 38),
#   datetime.datetime(2023, 1, 22, 8, 45, 40),
#   'banana',
#   1),
#  (15200,
#   15576,
#   22,
#   '641336ef02e3074c750bc961',
#   '64132ef662f97d5858f87aba',
#   '64132e0fa1b98612a1366a0a',
#   datetime.datetime(2021, 12, 30, 10, 2, 3),
#   datetime.datetime(2023, 1, 10, 12, 27, 32),
#   'banana',
#   0),
#  (15007,
#   15581,
#   21,
#   '641336ef02f1e722d04da32a',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f49625262850d71ab',
#   datetime.datetime(2021, 6, 20, 2, 28, 6),
#   datetime.datetime(2023, 1, 15, 7, 28, 42),
#   'strawberry',
#   1),
#  (15103,
#   15621,
#   33,
#   '641336ef02fa8119a298db89',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f63537c3b711d2a83',
#   datetime.datetime(2021, 9, 24, 9, 41, 18),
#   datetime.datetime(2023, 2, 24, 6, 48, 23),
#   'strawberry',
#   0),
#  (15245,
#   15583,
#   21,
#   '641336ef02fadadc327c40d7',
#   '64132ef6eea665cc154f614a',
#   '64132e0f76b4e9b5fc6496c6',
#   datetime.datetime(2022, 2, 13, 9, 26, 21),
#   datetime.datetime(2023, 1, 17, 5, 40, 33),
#   'apple',
#   1),
#  (14909,
#   15608,
#   29,
#   '641336ef03003d636fee2ac9',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f0abcd78da3792cfe',
#   datetime.datetime(2021, 3, 14, 1, 47, 7),
#   datetime.datetime(2023, 2, 11, 8, 57, 58),
#   'strawberry',
#   1),
#  (14894,
#   15571,
#   13,
#   '641336ef03037553fabdb3a7',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f9647ed73a005c271',
#   datetime.datetime(2021, 2, 27, 1, 37, 34),
#   datetime.datetime(2023, 1, 5, 2, 20, 12),
#   'banana',
#   1),
#  (15024,
#   15630,
#   1,
#   '641336ef03045a8eac969afd',
#   '64132ef662f97d5858f87aba',
#   '64132e0f022a91f2806aaefe',
#   datetime.datetime(2021, 7, 7, 3, 6, 18),
#   datetime.datetime(2023, 3, 5, 5, 0, 10),
#   'strawberry',
#   0),
#  (15374,
#   15599,
#   13,
#   '641336ef030d942d7a2493f2',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f56a8e4996c9497b4',
#   datetime.datetime(2022, 6, 22, 3, 58, 25),
#   datetime.datetime(2023, 2, 2, 8, 54, 56),
#   'apple',
#   1),
#  (15515,
#   15612,
#   5,
#   '641336ef03189c4a6427050b',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f56dd370a14cd262a',
#   datetime.datetime(2022, 11, 10, 4, 42, 37),
#   datetime.datetime(2023, 2, 15, 7, 41, 1),
#   'strawberry',
#   1),
#  (15194,
#   15612,
#   29,
#   '641336ef031c2bc868c94bf6',
#   '64132ef6eea665cc154f614a',
#   '64132e0f85b016750b1e4f8e',
#   datetime.datetime(2021, 12, 24, 3, 58, 11),
#   datetime.datetime(2023, 2, 15, 9, 2, 55),
#   'banana',
#   1),
#  (15051,
#   15616,
#   3,
#   '641336ef032103dc219528ac',
#   '64132ef6eea665cc154f614a',
#   '64132e0f7aee8254eafaa63a',
#   datetime.datetime(2021, 8, 3, 1, 14, 34),
#   datetime.datetime(2023, 2, 19, 11, 39, 24),
#   'apple',
#   0),
#  (15230,
#   15572,
#   6,
#   '641336ef032a6d4c4592ffaa',
#   '64132ef662f97d5858f87aba',
#   '64132e0faa55e10ce7ee68a3',
#   datetime.datetime(2022, 1, 29, 1, 10, 31),
#   datetime.datetime(2023, 1, 6, 5, 19, 57),
#   'apple',
#   0),
#  (14884,
#   15583,
#   5,
#   '641336ef032d8fce53700eee',
#   '64132ef6eea665cc154f614a',
#   '64132e0f49625262850d71ab',
#   datetime.datetime(2021, 2, 17, 5, 10, 59),
#   datetime.datetime(2023, 1, 17, 10, 42, 6),
#   'strawberry',
#   0),
#  (15402,
#   15615,
#   63,
#   '641336ef033043c3452898ad',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f8ae9531161eb5f9d',
#   datetime.datetime(2022, 7, 20, 3, 39, 54),
#   datetime.datetime(2023, 2, 18, 7, 27, 47),
#   'apple',
#   0),
#  (14987,
#   15610,
#   4,
#   '641336ef033a95c0184064e9',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f8df1cb7b954fecf9',
#   datetime.datetime(2021, 5, 31, 3, 59, 34),
#   datetime.datetime(2023, 2, 13, 9, 55, 37),
#   'apple',
#   0),
#  (15366,
#   15633,
#   6,
#   '641336ef034041f8e33f9e5c',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f0abcd78da3792cfe',
#   datetime.datetime(2022, 6, 14, 12, 4, 6),
#   datetime.datetime(2023, 3, 8, 1, 25, 56),
#   'banana',
#   1),
#  (15352,
#   15637,
#   21,
#   '641336ef03422ecc7458f511',
#   '64132ef68637da8c371cdc09',
#   '64132e0f00e22f4ac7b67520',
#   datetime.datetime(2022, 5, 31, 10, 38, 53),
#   datetime.datetime(2023, 3, 12, 12, 21, 40),
#   'strawberry',
#   0),
#  (14899,
#   15637,
#   4,
#   '641336ef034c1becc7b7e37e',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f8ae9531161eb5f9d',
#   datetime.datetime(2021, 3, 4, 9, 45, 50),
#   datetime.datetime(2023, 3, 12, 1, 38, 40),
#   'banana',
#   0),
#  (14888,
#   15634,
#   63,
#   '641336ef035238ca676a50e3',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0feb28dcda49522904',
#   datetime.datetime(2021, 2, 21, 1, 26, 23),
#   datetime.datetime(2023, 3, 9, 9, 2, 4),
#   'strawberry',
#   1),
#  (15182,
#   15637,
#   2,
#   '641336ef03536bea448ea837',
#   '64132ef68637da8c371cdc09',
#   '64132e0fb3add2bba99bcb24',
#   datetime.datetime(2021, 12, 12, 1, 55, 9),
#   datetime.datetime(2023, 3, 12, 3, 35, 49),
#   'strawberry',
#   1),
#  (14914,
#   15628,
#   33,
#   '641336ef0354d034ca7b23ec',
#   '64132ef68637da8c371cdc09',
#   '64132e0f7aee8254eafaa63a',
#   datetime.datetime(2021, 3, 19, 12, 23, 31),
#   datetime.datetime(2023, 3, 3, 7, 50, 20),
#   'apple',
#   0),
#  (14953,
#   15619,
#   3,
#   '641336ef036128166947d7ac',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f1c3cdc367a6667aa',
#   datetime.datetime(2021, 4, 27, 9, 30, 3),
#   datetime.datetime(2023, 2, 22, 9, 11, 35),
#   'banana',
#   0),
#  (15377,
#   15572,
#   13,
#   '641336ef0365b9ba3ed85c1a',
#   '64132ef662f97d5858f87aba',
#   '64132e0fbb8283fc0ab24791',
#   datetime.datetime(2022, 6, 25, 3, 41, 37),
#   datetime.datetime(2023, 1, 6, 2, 28, 38),
#   'banana',
#   1),
#  (15133,
#   15602,
#   9,
#   '641336ef0369b370f38b9437',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f05e9b1d120893ffe',
#   datetime.datetime(2021, 10, 24, 10, 2, 45),
#   datetime.datetime(2023, 2, 5, 11, 16, 30),
#   'banana',
#   1),
#  (15027,
#   15575,
#   39,
#   '641336ef036e1208a30ac1b8',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0ff31bfea3ecc4d0b6',
#   datetime.datetime(2021, 7, 10, 5, 31, 18),
#   datetime.datetime(2023, 1, 9, 8, 40, 51),
#   'apple',
#   1),
#  (15088,
#   15577,
#   10,
#   '641336ef037ffec9175cbcf0',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0fc77ec324b4a3b1d6',
#   datetime.datetime(2021, 9, 9, 1, 48, 51),
#   datetime.datetime(2023, 1, 11, 7, 51, 8),
#   'banana',
#   0),
#  (15491,
#   15589,
#   29,
#   '641336ef0381981fa76a0097',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f00e22f4ac7b67520',
#   datetime.datetime(2022, 10, 17, 2, 36, 44),
#   datetime.datetime(2023, 1, 23, 5, 19, 20),
#   'apple',
#   0),
#  (15322,
#   15600,
#   9,
#   '641336ef038218c5aa140bd1',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f1c3cdc367a6667aa',
#   datetime.datetime(2022, 5, 1, 1, 9, 2),
#   datetime.datetime(2023, 2, 3, 9, 19, 8),
#   'banana',
#   1),
#  (14956,
#   15609,
#   15,
#   '641336ef03829692e9ecdf53',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f74cda6acaa908563',
#   datetime.datetime(2021, 4, 30, 1, 30, 47),
#   datetime.datetime(2023, 2, 12, 6, 37, 54),
#   'strawberry',
#   0),
#  (15168,
#   15612,
#   0,
#   '641336ef038684a516afec04',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f5db21511f29bd2c3',
#   datetime.datetime(2021, 11, 28, 5, 8, 26),
#   datetime.datetime(2023, 2, 15, 6, 26, 4),
#   'banana',
#   1),
#  (15519,
#   15590,
#   33,
#   '641336ef0386e27560648d94',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f21cc4fc3bf2da26f',
#   datetime.datetime(2022, 11, 14, 4, 49),
#   datetime.datetime(2023, 1, 24, 11, 46, 38),
#   'banana',
#   0),
#  (15387,
#   15584,
#   9,
#   '641336ef038cdf423118e3ce',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f25f70db60e2eeb8e',
#   datetime.datetime(2022, 7, 5, 7, 54, 4),
#   datetime.datetime(2023, 1, 18, 12, 10, 9),
#   'banana',
#   1),
#  (15560,
#   15632,
#   39,
#   '641336ef0396f3db2edd29fc',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f5db21511f29bd2c3',
#   datetime.datetime(2022, 12, 25, 7, 51, 20),
#   datetime.datetime(2023, 3, 7, 12, 29, 47),
#   'banana',
#   0),
#  (14942,
#   15589,
#   0,
#   '641336ef03a4d2ab404218e4',
#   '64132ef68637da8c371cdc09',
#   '64132e0fd9d750210c1746a1',
#   datetime.datetime(2021, 4, 16, 3, 41, 34),
#   datetime.datetime(2023, 1, 23, 9, 54, 35),
#   'apple',
#   1),
#  (15218,
#   15616,
#   1,
#   '641336ef03ad2402f3eafd69',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0ff31bfea3ecc4d0b6',
#   datetime.datetime(2022, 1, 17, 11, 23, 30),
#   datetime.datetime(2023, 2, 19, 6, 56, 47),
#   'apple',
#   1),
#  (15421,
#   15569,
#   13,
#   '641336ef03ae306791bfc99e',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f0c020ecd45aea2db',
#   datetime.datetime(2022, 8, 8, 1, 36, 36),
#   datetime.datetime(2023, 1, 3, 2, 26, 44),
#   'apple',
#   1),
#  (15222,
#   15631,
#   10,
#   '641336ef03bca1f33ff8d066',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fe57d5c5c32addeec',
#   datetime.datetime(2022, 1, 21, 9, 51, 35),
#   datetime.datetime(2023, 3, 6, 1, 11, 31),
#   'banana',
#   1),
#  (15197,
#   15589,
#   22,
#   '641336ef03c394c639aeabea',
#   '64132ef68637da8c371cdc09',
#   '64132e0fddc4fe73fd258a24',
#   datetime.datetime(2021, 12, 27, 9, 53, 9),
#   datetime.datetime(2023, 1, 23, 7, 34, 36),
#   'banana',
#   0),
#  (15042,
#   15575,
#   63,
#   '641336ef03c3edfb77309d59',
#   '64132ef662f97d5858f87aba',
#   '64132e0f1eeec2acd297c0e9',
#   datetime.datetime(2021, 7, 25, 11, 16, 25),
#   datetime.datetime(2023, 1, 9, 11, 25, 39),
#   'banana',
#   1),
#  (15193,
#   15599,
#   4,
#   '641336ef03c472ffe9d23210',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f6f7f7af7c4dfe156',
#   datetime.datetime(2021, 12, 23, 12, 36, 36),
#   datetime.datetime(2023, 2, 2, 11, 12, 33),
#   'strawberry',
#   0),
#  (15034,
#   15598,
#   33,
#   '641336ef03c98db9e2995bc3',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fd3bdca816cd9ac2f',
#   datetime.datetime(2021, 7, 17, 8, 50, 47),
#   datetime.datetime(2023, 2, 1, 12, 36, 4),
#   'apple',
#   0),
#  (14907,
#   15634,
#   3,
#   '641336ef03ca7428b26378fd',
#   '64132ef662f97d5858f87aba',
#   '64132e0f861fcfbc0c1ca217',
#   datetime.datetime(2021, 3, 12, 3, 39, 25),
#   datetime.datetime(2023, 3, 9, 4, 0, 9),
#   'apple',
#   0),
#  (15466,
#   15570,
#   3,
#   '641336ef03d03699f0f34781',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f4884b463e3fa4bb5',
#   datetime.datetime(2022, 9, 22, 5, 21, 4),
#   datetime.datetime(2023, 1, 4, 3, 41, 43),
#   'strawberry',
#   1),
#  (15446,
#   15591,
#   0,
#   '641336ef03e02473fe91b689',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0fac889c7cbd7ebda3',
#   datetime.datetime(2022, 9, 2, 2, 19, 34),
#   datetime.datetime(2023, 1, 25, 1, 57, 16),
#   'strawberry',
#   1),
#  (14868,
#   15632,
#   1,
#   '641336ef03e0c2706dd00495',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0fd287835096499eed',
#   datetime.datetime(2021, 2, 1, 1, 2, 33),
#   datetime.datetime(2023, 3, 7, 4, 10, 4),
#   'apple',
#   0),
#  (15443,
#   15630,
#   0,
#   '641336ef03e1342b1128d9f4',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f6f7f7af7c4dfe156',
#   datetime.datetime(2022, 8, 30, 7, 54, 11),
#   datetime.datetime(2023, 3, 5, 8, 12, 59),
#   'strawberry',
#   1),
#  (15048,
#   15603,
#   9,
#   '641336ef03e257cca90565ba',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0fc8ad114d29212998',
#   datetime.datetime(2021, 7, 31, 3, 48, 16),
#   datetime.datetime(2023, 2, 6, 2, 0, 54),
#   'apple',
#   0),
#  (15291,
#   15639,
#   6,
#   '641336ef03e30c4a04860717',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f8ae9531161eb5f9d',
#   datetime.datetime(2022, 3, 31, 7, 9, 37),
#   datetime.datetime(2023, 3, 14, 8, 54, 29),
#   'apple',
#   1),
#  (15240,
#   15583,
#   34,
#   '641336ef03e4d237340d382a',
#   '64132ef6c9c22c95893e388b',
#   '64132e0fc77ec324b4a3b1d6',
#   datetime.datetime(2022, 2, 8, 4, 9, 26),
#   datetime.datetime(2023, 1, 17, 6, 24, 39),
#   'strawberry',
#   1),
#  (15302,
#   15609,
#   6,
#   '641336ef03e874283f44cffb',
#   '64132ef68637da8c371cdc09',
#   '64132e0fe14d128d168160e4',
#   datetime.datetime(2022, 4, 11, 1, 51, 29),
#   datetime.datetime(2023, 2, 12, 10, 28, 45),
#   'strawberry',
#   0),
#  (14940,
#   15595,
#   9,
#   '641336ef03f409e53ad29fee',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0ff99f08aa40f089ae',
#   datetime.datetime(2021, 4, 14, 8, 51, 49),
#   datetime.datetime(2023, 1, 29, 5, 7, 58),
#   'apple',
#   0),
#  (15348,
#   15632,
#   63,
#   '641336ef03fd0bb426faa39d',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f48ad8ae93e504d33',
#   datetime.datetime(2022, 5, 27, 10, 8, 46),
#   datetime.datetime(2023, 3, 7, 12, 21, 17),
#   'strawberry',
#   1),
#  (15502,
#   15626,
#   63,
#   '641336ef040af1fa2affc4e3',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f5db21511f29bd2c3',
#   datetime.datetime(2022, 10, 28, 12, 44, 15),
#   datetime.datetime(2023, 3, 1, 9, 28),
#   'strawberry',
#   0),
#  (15516,
#   15583,
#   10,
#   '641336ef041cb050fe7041a6',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f407b51b8b5dc2dba',
#   datetime.datetime(2022, 11, 11, 7, 4, 34),
#   datetime.datetime(2023, 1, 17, 3, 59, 12),
#   'strawberry',
#   1),
#  (14939,
#   15586,
#   39,
#   '641336ef041e744c9327522d',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fd0fd03a2161eade3',
#   datetime.datetime(2021, 4, 13, 8, 3, 41),
#   datetime.datetime(2023, 1, 20, 10, 52, 59),
#   'strawberry',
#   0),
#  (14946,
#   15627,
#   4,
#   '641336ef0422399f4166a75f',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f022a91f2806aaefe',
#   datetime.datetime(2021, 4, 20, 12, 47, 47),
#   datetime.datetime(2023, 3, 2, 1, 44, 36),
#   'strawberry',
#   1),
#  (15553,
#   15578,
#   10,
#   '641336ef04252bcb6b4523f7',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f05f9e9ca1e250a65',
#   datetime.datetime(2022, 12, 18, 5, 14, 17),
#   datetime.datetime(2023, 1, 12, 5, 15, 10),
#   'apple',
#   1),
#  (15110,
#   15625,
#   13,
#   '641336ef04258bb83fdc6b90',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fc7534e992bafa834',
#   datetime.datetime(2021, 10, 1, 1, 25, 17),
#   datetime.datetime(2023, 2, 28, 2, 5, 36),
#   'banana',
#   0),
#  (15157,
#   15573,
#   2,
#   '641336ef042af0ebbcc9a02b',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f21cc4fc3bf2da26f',
#   datetime.datetime(2021, 11, 17, 12, 11, 44),
#   datetime.datetime(2023, 1, 7, 2, 8, 57),
#   'apple',
#   1),
#  (15242,
#   15579,
#   63,
#   '641336ef042e43a770be4a2c',
#   '64132ef662f97d5858f87aba',
#   '64132e0f1eeec2acd297c0e9',
#   datetime.datetime(2022, 2, 10, 1, 55, 22),
#   datetime.datetime(2023, 1, 13, 3, 3, 21),
#   'strawberry',
#   0),
#  (15118,
#   15575,
#   6,
#   '641336ef042f901407f036be',
#   '64132ef662f97d5858f87aba',
#   '64132e0ff7c0a95b1a0707b0',
#   datetime.datetime(2021, 10, 9, 7, 1, 9),
#   datetime.datetime(2023, 1, 9, 5, 43, 2),
#   'apple',
#   0),
#  (15298,
#   15573,
#   3,
#   '641336ef0431c58ef5fb523f',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0ff24b4a855793a5cf',
#   datetime.datetime(2022, 4, 7, 11, 33, 12),
#   datetime.datetime(2023, 1, 7, 6, 40, 27),
#   'banana',
#   0),
#  (14941,
#   15575,
#   13,
#   '641336ef04353161c80b779e',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f407b51b8b5dc2dba',
#   datetime.datetime(2021, 4, 15, 8, 58, 4),
#   datetime.datetime(2023, 1, 9, 5, 42, 58),
#   'banana',
#   0),
#  (15110,
#   15618,
#   63,
#   '641336ef043535824e40c113',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f7dc97b755f68884d',
#   datetime.datetime(2021, 10, 1, 4, 34, 39),
#   datetime.datetime(2023, 2, 21, 10, 31, 22),
#   'apple',
#   0),
#  (15056,
#   15641,
#   29,
#   '641336ef0437b88683796344',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f35c0faf75c5ad3e1',
#   datetime.datetime(2021, 8, 8, 5, 38),
#   datetime.datetime(2023, 3, 16, 7, 1, 10),
#   'banana',
#   0),
#  (15415,
#   15630,
#   15,
#   '641336ef043ed413a4d32d0b',
#   '64132ef662f97d5858f87aba',
#   '64132e0f0c020ecd45aea2db',
#   datetime.datetime(2022, 8, 2, 8, 48, 57),
#   datetime.datetime(2023, 3, 5, 12, 24, 45),
#   'apple',
#   0),
#  (14948,
#   15572,
#   63,
#   '641336ef044219639a623586',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f407b51b8b5dc2dba',
#   datetime.datetime(2021, 4, 22, 1, 45, 27),
#   datetime.datetime(2023, 1, 6, 12, 21, 18),
#   'strawberry',
#   1),
#  (15501,
#   15633,
#   63,
#   '641336ef0444a43a82839086',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0fa9c7a5c639898a57',
#   datetime.datetime(2022, 10, 27, 5, 23, 5),
#   datetime.datetime(2023, 3, 8, 3, 59, 55),
#   'banana',
#   0),
#  (15323,
#   15638,
#   21,
#   '641336ef0448d28add32ea3e',
#   '64132ef68637da8c371cdc09',
#   '64132e0f72bb82a25ea19ecb',
#   datetime.datetime(2022, 5, 2, 3, 40, 10),
#   datetime.datetime(2023, 3, 13, 1, 50, 8),
#   'apple',
#   0),
#  (14962,
#   15600,
#   29,
#   '641336ef044bebfa5487032d',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f9bbde2888d09e570',
#   datetime.datetime(2021, 5, 6, 1, 0, 39),
#   datetime.datetime(2023, 2, 3, 7, 16, 37),
#   'strawberry',
#   0),
#  (15509,
#   15621,
#   2,
#   '641336ef0453787b0458ccbe',
#   '64132ef662f97d5858f87aba',
#   '64132e0f90329937be6d5b65',
#   datetime.datetime(2022, 11, 4, 1, 12, 38),
#   datetime.datetime(2023, 2, 24, 7, 42, 2),
#   'banana',
#   0),
#  (15219,
#   15592,
#   6,
#   '641336ef04621f5c438dfaf5',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f63c1a33ae32d7a99',
#   datetime.datetime(2022, 1, 18, 11, 56, 40),
#   datetime.datetime(2023, 1, 26, 11, 16, 25),
#   'apple',
#   1),
#  (14962,
#   15592,
#   9,
#   '641336ef0462a1d05a8104c7',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f1c3cdc367a6667aa',
#   datetime.datetime(2021, 5, 6, 11, 18, 30),
#   datetime.datetime(2023, 1, 26, 7, 10, 2),
#   'apple',
#   1),
#  (15269,
#   15586,
#   6,
#   '641336ef0464d733fc820e60',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f5db21511f29bd2c3',
#   datetime.datetime(2022, 3, 9, 9, 36, 41),
#   datetime.datetime(2023, 1, 20, 8, 41, 34),
#   'banana',
#   0),
#  (15466,
#   15585,
#   15,
#   '641336ef04699f0fef14e8a9',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f708218333d413c4c',
#   datetime.datetime(2022, 9, 22, 2, 57, 43),
#   datetime.datetime(2023, 1, 19, 8, 7, 23),
#   'apple',
#   0),
#  (15339,
#   15600,
#   3,
#   '641336ef0473f42857bacfee',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fc26ed10af69ef2e3',
#   datetime.datetime(2022, 5, 18, 10, 48, 16),
#   datetime.datetime(2023, 2, 3, 3, 52, 15),
#   'apple',
#   0),
#  (15550,
#   15589,
#   0,
#   '641336ef04773e1326039d7e',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0fe57d5c5c32addeec',
#   datetime.datetime(2022, 12, 15, 5, 22, 45),
#   datetime.datetime(2023, 1, 23, 3, 55, 47),
#   'banana',
#   0),
#  (14862,
#   15589,
#   9,
#   '641336ef0480e1720aed8e25',
#   '64132ef68637da8c371cdc09',
#   '64132e0fccaa6cd8f625d942',
#   datetime.datetime(2021, 1, 26, 1, 22, 56),
#   datetime.datetime(2023, 1, 23, 12, 2, 27),
#   'banana',
#   1),
#  (14864,
#   15604,
#   22,
#   '641336ef04892398fdf1a300',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f74cda6acaa908563',
#   datetime.datetime(2021, 1, 28, 11, 14, 37),
#   datetime.datetime(2023, 2, 7, 11, 2, 56),
#   'banana',
#   0),
#  (15423,
#   15585,
#   34,
#   '641336ef04923e429cff17b0',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0faa55e10ce7ee68a3',
#   datetime.datetime(2022, 8, 10, 5, 47, 20),
#   datetime.datetime(2023, 1, 19, 4, 33, 30),
#   'banana',
#   1),
#  (14912,
#   15626,
#   10,
#   '641336ef049ccf1a447ff847',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0fb611e00924b0b8e0',
#   datetime.datetime(2021, 3, 17, 5, 36, 24),
#   datetime.datetime(2023, 3, 1, 4, 2, 42),
#   'strawberry',
#   0),
#  (14882,
#   15605,
#   6,
#   '641336ef049f7ac8ef046b19',
#   '64132ef6eea665cc154f614a',
#   '64132e0fbfc9f83e9c20d1a2',
#   datetime.datetime(2021, 2, 15, 9, 45, 49),
#   datetime.datetime(2023, 2, 8, 7, 15, 18),
#   'apple',
#   0),
#  (15139,
#   15618,
#   6,
#   '641336ef04a01564584ab022',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f95dc386b40202460',
#   datetime.datetime(2021, 10, 30, 10, 8, 30),
#   datetime.datetime(2023, 2, 21, 4, 20, 47),
#   'apple',
#   1),
#  (14958,
#   15634,
#   13,
#   '641336ef04a7efc18d4d3e26',
#   '64132ef68637da8c371cdc09',
#   '64132e0fe8e5688a81c56b8a',
#   datetime.datetime(2021, 5, 2, 5, 43, 20),
#   datetime.datetime(2023, 3, 9, 5, 30, 3),
#   'strawberry',
#   1),
#  (15443,
#   15639,
#   5,
#   '641336ef04b069bfb75759e6',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fb3add2bba99bcb24',
#   datetime.datetime(2022, 8, 30, 1, 13, 1),
#   datetime.datetime(2023, 3, 14, 4, 16, 21),
#   'apple',
#   1),
#  (15467,
#   15581,
#   9,
#   '641336ef04b2da9beb472f61',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f4884b463e3fa4bb5',
#   datetime.datetime(2022, 9, 23, 3, 20, 3),
#   datetime.datetime(2023, 1, 15, 4, 9, 30),
#   'strawberry',
#   1),
#  (15331,
#   15573,
#   21,
#   '641336ef04bf25abbc9f63a9',
#   '64132ef6eea665cc154f614a',
#   '64132e0ff99f08aa40f089ae',
#   datetime.datetime(2022, 5, 10, 7, 18, 5),
#   datetime.datetime(2023, 1, 7, 6, 32, 41),
#   'strawberry',
#   1),
#  (15352,
#   15595,
#   34,
#   '641336ef04c4934f31c793d5',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f56dd370a14cd262a',
#   datetime.datetime(2022, 5, 31, 3, 31, 39),
#   datetime.datetime(2023, 1, 29, 8, 38, 53),
#   'strawberry',
#   1),
#  (14938,
#   15614,
#   29,
#   '641336ef04ce2b65e1114cc6',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f7592c8eadca451f9',
#   datetime.datetime(2021, 4, 12, 2, 51, 35),
#   datetime.datetime(2023, 2, 17, 6, 3, 31),
#   'strawberry',
#   1),
#  (14913,
#   15593,
#   34,
#   '641336ef04d49522d53ad121',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f9bbde2888d09e570',
#   datetime.datetime(2021, 3, 18, 10, 27, 1),
#   datetime.datetime(2023, 1, 27, 5, 11, 9),
#   'banana',
#   1),
#  (15505,
#   15583,
#   5,
#   '641336ef04d7c91ee1766e7c',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f708218333d413c4c',
#   datetime.datetime(2022, 10, 31, 3, 12, 55),
#   datetime.datetime(2023, 1, 17, 1, 8, 33),
#   'apple',
#   1),
#  (14933,
#   15568,
#   1,
#   '641336ef04db7911a4fdc7b3',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0fe7a0ca7f994cca17',
#   datetime.datetime(2021, 4, 7, 3, 12, 23),
#   datetime.datetime(2023, 1, 2, 9, 37, 43),
#   'strawberry',
#   1),
#  (15547,
#   15622,
#   22,
#   '641336ef04e587c859ee00c1',
#   '64132ef662f97d5858f87aba',
#   '64132e0fa078fea397f180eb',
#   datetime.datetime(2022, 12, 12, 5, 46, 55),
#   datetime.datetime(2023, 2, 25, 5, 24),
#   'apple',
#   0),
#  (15096,
#   15568,
#   15,
#   '641336ef04e8e0bd23fbb3f5',
# ...
#   'strawberry',
#   1),
#  (15466,
#   15580,
#   6,
#   '641336ef160b803a57bcc433',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f483bdb42b75e860c',
#   datetime.datetime(2022, 9, 22, 7, 22, 21),
#   datetime.datetime(2023, 1, 14, 4, 32, 17),
#   'strawberry',
#   1),
#  (15056,
#   15568,
#   6,
#   '641336ef161020e1bed67032',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f67e98be3094ec5c9',
#   datetime.datetime(2021, 8, 8, 7, 19, 3),
#   datetime.datetime(2023, 1, 2, 4, 25, 38),
#   'banana',
#   0),
#  (14904,
#   15584,
#   4,
#   '641336ef1617e01089e4e8e8',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fe57d5c5c32addeec',
#   datetime.datetime(2021, 3, 9, 12, 0, 27),
#   datetime.datetime(2023, 1, 18, 7, 34, 20),
#   'banana',
#   0),
#  (14918,
#   15579,
#   22,
#   '641336ef16249836ac8752ff',
#   '64132ef6eea665cc154f614a',
#   '64132e0fb3c06ddc6c896f5b',
#   datetime.datetime(2021, 3, 23, 11, 38, 26),
#   datetime.datetime(2023, 1, 13, 2, 11, 31),
#   'apple',
#   1),
#  (14943,
#   15577,
#   63,
#   '641336ef1626b797e5f8b3c6',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f56dd370a14cd262a',
#   datetime.datetime(2021, 4, 17, 9, 13, 55),
#   datetime.datetime(2023, 1, 11, 8, 6, 7),
#   'strawberry',
#   1),
#  (15149,
#   15603,
#   6,
#   '641336ef16280e207fdb91f5',
#   '64132ef68637da8c371cdc09',
#   '64132e0f19d8c115ba93536c',
#   datetime.datetime(2021, 11, 9, 10, 5, 1),
#   datetime.datetime(2023, 2, 6, 10, 43, 35),
#   'strawberry',
#   0),
#  (15229,
#   15635,
#   0,
#   '641336ef16291d70f8572e13',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f38c6485f069d4421',
#   datetime.datetime(2022, 1, 28, 7, 49, 35),
#   datetime.datetime(2023, 3, 10, 9, 10, 19),
#   'banana',
#   0),
#  (14931,
#   15603,
#   22,
#   '641336ef162fba9f991502ec',
#   '64132ef6eea665cc154f614a',
#   '64132e0f0bda9c4ebba64c82',
#   datetime.datetime(2021, 4, 5, 5, 13, 54),
#   datetime.datetime(2023, 2, 6, 3, 25, 14),
#   'strawberry',
#   0),
#  (15399,
#   15617,
#   1,
#   '641336ef164716404573a42c',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f7592c8eadca451f9',
#   datetime.datetime(2022, 7, 17, 6, 10, 47),
#   datetime.datetime(2023, 2, 20, 3, 42, 11),
#   'apple',
#   1),
#  (14867,
#   15612,
#   29,
#   '641336ef16481b78f702a019',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f3e421185043a4e7b',
#   datetime.datetime(2021, 1, 31, 12, 55, 32),
#   datetime.datetime(2023, 2, 15, 4, 34, 20),
#   'apple',
#   1),
#  (14895,
#   15582,
#   34,
#   '641336ef164a720b41501772',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fd287835096499eed',
#   datetime.datetime(2021, 2, 28, 3, 42, 19),
#   datetime.datetime(2023, 1, 16, 9, 35, 36),
#   'banana',
#   0),
#  (15406,
#   15568,
#   6,
#   '641336ef164ba2364bde657d',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fa1b98612a1366a0a',
#   datetime.datetime(2022, 7, 24, 6, 37, 3),
#   datetime.datetime(2023, 1, 2, 7, 33, 16),
#   'apple',
#   0),
#  (15097,
#   15575,
#   39,
#   '641336ef164fbb38bbd1110d',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f25f70db60e2eeb8e',
#   datetime.datetime(2021, 9, 18, 4, 6, 17),
#   datetime.datetime(2023, 1, 9, 8, 56, 39),
#   'apple',
#   1),
#  (15540,
#   15639,
#   0,
#   '641336ef165b48442a7253a7',
#   '64132ef6eea665cc154f614a',
#   '64132e0f0abcd78da3792cfe',
#   datetime.datetime(2022, 12, 5, 11, 57, 50),
#   datetime.datetime(2023, 3, 14, 5, 16, 24),
#   'banana',
#   1),
#  (15309,
#   15618,
#   39,
#   '641336ef165b4bf3dadfafa4',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f21cc4fc3bf2da26f',
#   datetime.datetime(2022, 4, 18, 11, 0, 56),
#   datetime.datetime(2023, 2, 21, 8, 55, 53),
#   'banana',
#   1),
#  (15290,
#   15597,
#   63,
#   '641336ef165d01f02a3adcb3',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f56dd370a14cd262a',
#   datetime.datetime(2022, 3, 30, 5, 0, 19),
#   datetime.datetime(2023, 1, 31, 10, 43),
#   'apple',
#   0),
#  (15239,
#   15617,
#   10,
#   '641336ef165dc02c3bab25f2',
#   '64132ef662f97d5858f87aba',
#   '64132e0fbb8283fc0ab24791',
#   datetime.datetime(2022, 2, 7, 10, 37, 16),
#   datetime.datetime(2023, 2, 20, 5, 24, 17),
#   'strawberry',
#   0),
#  (15056,
#   15636,
#   33,
#   '641336ef16656a7e0929204d',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f90329937be6d5b65',
#   datetime.datetime(2021, 8, 8, 8, 45, 30),
#   datetime.datetime(2023, 3, 11, 2, 1, 29),
#   'banana',
#   1),
#  (15308,
#   15577,
#   13,
#   '641336ef1667e82156598b65',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0fec1b702b2378c379',
#   datetime.datetime(2022, 4, 17, 8, 21, 41),
#   datetime.datetime(2023, 1, 11, 8, 55, 23),
#   'apple',
#   0),
#  (15201,
#   15634,
#   3,
#   '641336ef166ac1f9d35f7197',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f8ae9531161eb5f9d',
#   datetime.datetime(2021, 12, 31, 8, 46, 36),
#   datetime.datetime(2023, 3, 9, 1, 16, 38),
#   'strawberry',
#   0),
#  (15491,
#   15613,
#   1,
#   '641336ef1678b55660b9051a',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f58ce216e866593d6',
#   datetime.datetime(2022, 10, 17, 11, 0),
#   datetime.datetime(2023, 2, 16, 3, 57, 55),
#   'apple',
#   0),
#  (15091,
#   15612,
#   5,
#   '641336ef167c83ff5a10463b',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f16e8266d4823236c',
#   datetime.datetime(2021, 9, 12, 4, 31, 19),
#   datetime.datetime(2023, 2, 15, 9, 57, 55),
#   'strawberry',
#   0),
#  (15509,
#   15589,
#   15,
#   '641336ef167eac6519d14953',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0fd9d750210c1746a1',
#   datetime.datetime(2022, 11, 4, 3, 51, 7),
#   datetime.datetime(2023, 1, 23, 4, 4, 14),
#   'banana',
#   1),
#  (15331,
#   15574,
#   39,
#   '641336ef16901e2f2ccd74db',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0fb3add2bba99bcb24',
#   datetime.datetime(2022, 5, 10, 12, 14, 36),
#   datetime.datetime(2023, 1, 8, 12, 6, 55),
#   'strawberry',
#   0),
#  (15532,
#   15616,
#   15,
#   '641336ef1699ebb9c61e315c',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0f29d8b74c6b1cb514',
#   datetime.datetime(2022, 11, 27, 7, 40, 26),
#   datetime.datetime(2023, 2, 19, 2, 31, 10),
#   'strawberry',
#   0),
#  (15352,
#   15612,
#   34,
#   '641336ef16a0fd5816e96410',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f022a91f2806aaefe',
#   datetime.datetime(2022, 5, 31, 5, 12, 36),
#   datetime.datetime(2023, 2, 15, 4, 54, 53),
#   'apple',
#   1),
#  (15321,
#   15613,
#   63,
#   '641336ef16a3e4a63370f409',
#   '64132ef6c9c22c95893e388b',
#   '64132e0fc7534e992bafa834',
#   datetime.datetime(2022, 4, 30, 3, 58, 31),
#   datetime.datetime(2023, 2, 16, 3, 5, 22),
#   'apple',
#   1),
#  (14922,
#   15594,
#   29,
#   '641336ef16a51340889d1461',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0ff99f08aa40f089ae',
#   datetime.datetime(2021, 3, 27, 7, 26, 54),
#   datetime.datetime(2023, 1, 28, 10, 59, 9),
#   'banana',
#   1),
#  (14926,
#   15571,
#   1,
#   '641336ef16ab1dca6acc4cfd',
#   '64132ef662f97d5858f87aba',
#   '64132e0f7dc97b755f68884d',
#   datetime.datetime(2021, 3, 31, 4, 9, 47),
#   datetime.datetime(2023, 1, 5, 5, 4, 42),
#   'banana',
#   1),
#  (15274,
#   15570,
#   39,
#   '641336ef16ae71f74b50322b',
#   '64132ef68637da8c371cdc09',
#   '64132e0ffe16938ae5708fb3',
#   datetime.datetime(2022, 3, 14, 3, 21, 12),
#   datetime.datetime(2023, 1, 4, 10, 4, 35),
#   'apple',
#   1),
#  (15043,
#   15610,
#   63,
#   '641336ef16b7dbb576f5ff09',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f56dd370a14cd262a',
#   datetime.datetime(2021, 7, 26, 4, 5, 39),
#   datetime.datetime(2023, 2, 13, 10, 1, 16),
#   'banana',
#   0),
#  (15318,
#   15587,
#   10,
#   '641336ef16d5c6a3b48e64e2',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f05e9b1d120893ffe',
#   datetime.datetime(2022, 4, 27, 8, 16, 13),
#   datetime.datetime(2023, 1, 21, 12, 37),
#   'banana',
#   0),
#  (15046,
#   15619,
#   0,
#   '641336ef16d81b72d9007935',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f861fcfbc0c1ca217',
#   datetime.datetime(2021, 7, 29, 3, 12, 39),
#   datetime.datetime(2023, 2, 22, 10, 14, 40),
#   'banana',
#   1),
#  (15414,
#   15629,
#   22,
#   '641336ef16de8740483e4d82',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f05e9b1d120893ffe',
#   datetime.datetime(2022, 8, 1, 11, 56, 49),
#   datetime.datetime(2023, 3, 4, 5, 54, 27),
#   'strawberry',
#   1),
#  (15260,
#   15638,
#   21,
#   '641336ef16fa1cfc9d145860',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0fe8e5688a81c56b8a',
#   datetime.datetime(2022, 2, 28, 7, 2, 4),
#   datetime.datetime(2023, 3, 13, 4, 56, 2),
#   'strawberry',
#   0),
#  (14847,
#   15636,
#   13,
#   '641336ef16ff323f31335353',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0fddc4fe73fd258a24',
#   datetime.datetime(2021, 1, 11, 6, 27, 35),
#   datetime.datetime(2023, 3, 11, 3, 6, 48),
#   'strawberry',
#   1),
#  (14900,
#   15607,
#   1,
#   '641336ef170b7a2b503ce2c1',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0ff31bfea3ecc4d0b6',
#   datetime.datetime(2021, 3, 5, 3, 56, 20),
#   datetime.datetime(2023, 2, 10, 9, 52, 37),
#   'apple',
#   0),
#  (15131,
#   15604,
#   13,
#   '641336ef170bb4f4cd4fd960',
#   '64132ef662f97d5858f87aba',
#   '64132e0f7847d1ad65a92102',
#   datetime.datetime(2021, 10, 22, 4, 8, 4),
#   datetime.datetime(2023, 2, 7, 8, 19, 27),
#   'apple',
#   0),
#  (15217,
#   15624,
#   34,
#   '641336ef1710df41c4a82c5a',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f74cda6acaa908563',
#   datetime.datetime(2022, 1, 16, 2, 24, 22),
#   datetime.datetime(2023, 2, 27, 2, 53, 32),
#   'banana',
#   0),
#  (15067,
#   15581,
#   9,
#   '641336ef17114a910930dbc5',
#   '64132ef6eea665cc154f614a',
#   '64132e0f0c020ecd45aea2db',
#   datetime.datetime(2021, 8, 19, 10, 27, 36),
#   datetime.datetime(2023, 1, 15, 8, 56, 42),
#   'apple',
#   0),
#  (15294,
#   15594,
#   0,
#   '641336ef17240cc58f165355',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f56dd370a14cd262a',
#   datetime.datetime(2022, 4, 3, 4, 53, 5),
#   datetime.datetime(2023, 1, 28, 12, 22, 53),
#   'banana',
#   0),
#  (15237,
#   15615,
#   63,
#   '641336ef172a15294916ce30',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f16e8266d4823236c',
#   datetime.datetime(2022, 2, 5, 9, 29, 32),
#   datetime.datetime(2023, 2, 18, 4, 31, 4),
#   'apple',
#   1),
#  (15514,
#   15575,
#   4,
#   '641336ef172d58bd21b05fd8',
#   '64132ef68637da8c371cdc09',
#   '64132e0f9647ed73a005c271',
#   datetime.datetime(2022, 11, 9, 7, 22, 43),
#   datetime.datetime(2023, 1, 9, 1, 15, 39),
#   'banana',
#   1),
#  (15232,
#   15625,
#   39,
#   '641336ef1732fd3cfcdff6f2',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f708218333d413c4c',
#   datetime.datetime(2022, 1, 31, 4, 50, 18),
#   datetime.datetime(2023, 2, 28, 12, 44, 24),
#   'banana',
#   1),
#  (15181,
#   15573,
#   0,
#   '641336ef173635cf9ec79f2f',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0fac889c7cbd7ebda3',
#   datetime.datetime(2021, 12, 11, 7, 58, 48),
#   datetime.datetime(2023, 1, 7, 2, 10, 2),
#   'apple',
#   0),
#  (15496,
#   15568,
#   5,
#   '641336ef173ce903f83d5323',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f6ed08d9ca49a70c4',
#   datetime.datetime(2022, 10, 22, 10, 26, 2),
#   datetime.datetime(2023, 1, 2, 2, 55, 12),
#   'apple',
#   1),
#  (15093,
#   15596,
#   29,
#   '641336ef1740d435a9f90200',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f8b3d3810100355b5',
#   datetime.datetime(2021, 9, 14, 5, 55, 21),
#   datetime.datetime(2023, 1, 30, 8, 51, 5),
#   'apple',
#   1),
#  (14863,
#   15595,
#   22,
#   '641336ef1741ecd0c1e1e39e',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0f555673bb72251b1d',
#   datetime.datetime(2021, 1, 27, 8, 50, 48),
#   datetime.datetime(2023, 1, 29, 6, 55, 14),
#   'apple',
#   1),
#  (14910,
#   15606,
#   29,
#   '641336ef17450fbd235bd3d1',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f7da24bcd8d8ca3fb',
#   datetime.datetime(2021, 3, 15, 11, 31, 43),
#   datetime.datetime(2023, 2, 9, 7, 37, 18),
#   'apple',
#   0),
#  (15534,
#   15613,
#   21,
#   '641336ef17477111c1291979',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0fb611e00924b0b8e0',
#   datetime.datetime(2022, 11, 29, 4, 31, 34),
#   datetime.datetime(2023, 2, 16, 2, 34, 28),
#   'banana',
#   1),
#  (15004,
#   15584,
#   39,
#   '641336ef174f2f711f47e992',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f05e9b1d120893ffe',
#   datetime.datetime(2021, 6, 17, 4, 31, 31),
#   datetime.datetime(2023, 1, 18, 12, 17, 32),
#   'banana',
#   1),
#  (14896,
#   15568,
#   22,
#   '641336ef1750c69dffffc231',
#   '64132ef6c9c22c95893e388b',
#   '64132e0f5dcfd2856d9f8337',
#   datetime.datetime(2021, 3, 1, 2, 13, 20),
#   datetime.datetime(2023, 1, 2, 5, 21),
#   'apple',
#   0),
#  (14947,
#   15637,
#   3,
#   '641336ef1759bfdcc5589f5c',
#   '64132ef662f97d5858f87aba',
#   '64132e0f7592c8eadca451f9',
#   datetime.datetime(2021, 4, 21, 4, 21, 20),
#   datetime.datetime(2023, 3, 12, 3, 29, 15),
#   'banana',
#   0),
#  (15154,
#   15636,
#   4,
#   '641336ef175cba175cd0b0a2',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0fe7a0ca7f994cca17',
#   datetime.datetime(2021, 11, 14, 1, 32, 50),
#   datetime.datetime(2023, 3, 11, 1, 19, 44),
#   'banana',
#   1),
#  (15157,
#   15589,
#   33,
#   '641336ef1760703f643f8be8',
#   '64132ef68637da8c371cdc09',
#   '64132e0f6f7f7af7c4dfe156',
#   datetime.datetime(2021, 11, 17, 8, 10, 44),
#   datetime.datetime(2023, 1, 23, 4, 42, 27),
#   'strawberry',
#   1),
#  (15311,
#   15602,
#   5,
#   '641336ef1763569e8051045a',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f5dcfd2856d9f8337',
#   datetime.datetime(2022, 4, 20, 3, 17, 44),
#   datetime.datetime(2023, 2, 5, 8, 15, 6),
#   'banana',
#   1),
#  (14877,
#   15569,
#   15,
#   '641336ef17690177d539103e',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fc7534e992bafa834',
#   datetime.datetime(2021, 2, 10, 3, 57, 37),
#   datetime.datetime(2023, 1, 3, 6, 2, 50),
#   'apple',
#   0),
#  (15325,
#   15636,
#   0,
#   '641336ef176dce421b1058b2',
#   '64132ef6c9c22c95893e388b',
#   '64132e0fbfc9f83e9c20d1a2',
#   datetime.datetime(2022, 5, 4, 4, 29, 16),
#   datetime.datetime(2023, 3, 11, 7, 48, 18),
#   'strawberry',
#   0),
#  (15283,
#   15608,
#   10,
#   '641336ef176dfe5feae22dd4',
#   '64132ef662f97d5858f87aba',
#   '64132e0fddc4fe73fd258a24',
#   datetime.datetime(2022, 3, 23, 1, 47, 15),
#   datetime.datetime(2023, 2, 11, 10, 4, 22),
#   'banana',
#   0),
#  (15430,
#   15568,
#   39,
#   '641336ef177123c879f4d769',
#   '64132ef662f97d5858f87aba',
#   '64132e0f8df1cb7b954fecf9',
#   datetime.datetime(2022, 8, 17, 2, 9, 29),
#   datetime.datetime(2023, 1, 2, 4, 48, 54),
#   'apple',
#   1),
#  (15334,
#   15580,
#   39,
#   '641336ef177586e4fff58512',
#   '64132ef68637da8c371cdc09',
#   '64132e0f861fcfbc0c1ca217',
#   datetime.datetime(2022, 5, 13, 1, 21, 45),
#   datetime.datetime(2023, 1, 14, 1, 6, 7),
#   'strawberry',
#   0),
#  (15110,
#   15593,
#   29,
#   '641336ef177ef67b86a2e8b7',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0f05f9e9ca1e250a65',
#   datetime.datetime(2021, 10, 1, 10, 22, 57),
#   datetime.datetime(2023, 1, 27, 4, 26, 27),
#   'strawberry',
#   1),
#  (15397,
#   15605,
#   2,
#   '641336ef1785ef6661b81b39',
#   '64132ef662f97d5858f87aba',
#   '64132e0fc8ad114d29212998',
#   datetime.datetime(2022, 7, 15, 8, 32, 56),
#   datetime.datetime(2023, 2, 8, 5, 41, 59),
#   'apple',
#   1),
#  (15565,
#   15625,
#   6,
#   '641336ef178d61c53e7e4395',
#   '64132ef68637da8c371cdc09',
#   '64132e0f1c3cdc367a6667aa',
#   datetime.datetime(2022, 12, 30, 7, 43, 22),
#   datetime.datetime(2023, 2, 28, 3, 43, 36),
#   'banana',
#   1),
#  (14952,
#   15603,
#   13,
#   '641336ef179d757326641344',
#   '64132ef6526eeb8b998e2d3c',
#   '64132e0fc7534e992bafa834',
#   datetime.datetime(2021, 4, 26, 10, 29, 16),
#   datetime.datetime(2023, 2, 6, 6, 42, 33),
#   'strawberry',
#   1),
#  (15421,
#   15570,
#   33,
#   '641336ef17a3fa756076d492',
#   '64132ef68637da8c371cdc09',
#   '64132e0ff7c0a95b1a0707b0',
#   datetime.datetime(2022, 8, 8, 5, 26, 41),
#   datetime.datetime(2023, 1, 4, 10, 57, 22),
#   'strawberry',
#   0),
#  (15470,
#   15594,
#   2,
#   '641336ef17a40a9a0287c101',
#   '64132ef6dca9067d51ca1b30',
#   '64132e0fa9c7a5c639898a57',
#   datetime.datetime(2022, 9, 26, 8, 33, 31),
#   datetime.datetime(2023, 1, 28, 4, 54, 6),
#   'apple',
#   1),
#  (15190,
#   15619,
#   29,
#   '641336ef17a99e8333713fa9',
#   '64132ef6f54b06e1ffb65fba',
#   '64132e0fe0f83495969d409d',
#   datetime.datetime(2021, 12, 20, 3, 56, 42),
#   datetime.datetime(2023, 2, 22, 9, 50, 37),
#   'strawberry',
#   1),
#  (15322,
#   15592,
#   63,
#   '641336ef17af554c5d49ce99',
#   '64132ef6ccd2d35a83c3544a',
#   '64132e0f56dd370a14cd262a',
#   datetime.datetime(2022, 5, 1, 1, 34, 4),
#   datetime.datetime(2023, 1, 26, 11, 14, 32),
#   'banana',
#   1),
#  (15293,
#   15623,
#   13,
#   '641336ef17b49e8d3b1707bb',
#   '64132ef6f991a3a1884f2cd0',
#   '64132e0f63c1a33ae32d7a99',
#   datetime.datetime(2022, 4, 2, 1, 54, 18),
#   datetime.datetime(2023, 2, 26, 2, 36, 53),
#   'banana',
#   0),
#  (15169,
#   15575,
#   13,
#   '641336ef17b75b0cc0aa4be4',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f1c3cdc367a6667aa',
#   datetime.datetime(2021, 11, 29, 4, 33, 53),
#   datetime.datetime(2023, 1, 9, 8, 43, 59),
#   'banana',
#   0),
#  (15536,
#   15590,
#   33,
#   '641336ef17b86d6dacf2da1d',
#   '64132ef64f72ae4d32dc3535',
#   '64132e0f9647ed73a005c271',
#   datetime.datetime(2022, 12, 1, 2, 54, 31),
#   datetime.datetime(2023, 1, 24, 8, 22, 23),
#   'strawberry',
#   1),
#  ...]
